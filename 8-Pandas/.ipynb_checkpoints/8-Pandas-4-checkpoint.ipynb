# %%
import numpy as np
import pandas as pd
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 27. Aggregate using one or more operations
# <pre>Usage: df.aggregate(func=None, axis=0, *args, **kwargs)
# Given Input:
# df = pd.read_csv('iris.csv')
#
# Requirement:
# Find out mean, median and std of each species.
# </pre>

# %%
df = pd.read_csv('iris.csv')
df.sample(3)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth             Name
# 144          6.7         3.3          5.7         2.5   Iris-virginica
# 82           5.8         2.7          3.9         1.2  Iris-versicolor
# 6            4.6         3.4          1.4         0.3      Iris-setosa

# %%
df.groupby('Name').agg(['std','mean','median'])
# Out:
#                 SepalLength               SepalWidth                \
#                         std   mean median        std   mean median
# Name
# Iris-setosa        0.352490  5.006    5.0   0.381024  3.418    3.4
# Iris-versicolor    0.516171  5.936    5.9   0.313798  2.770    2.8
# Iris-virginica     0.635880  6.588    6.5   0.322497  2.974    3.0
#
#                 PetalLength               PetalWidth
#                         std   mean median        std   mean median
# Name
# Iris-setosa        0.173511  1.464   1.50   0.107210  0.244    0.2
# Iris-versicolor    0.469911  4.260   4.35   0.197753  1.326    1.3
# Iris-virginica     0.551895  5.552   5.55   0.274650  2.026    2.0

# %% [markdown]
# ## 28. Call function on self producing a DataFrame with the same column
# <pre>Call func on self producing a DataFrame with
# the same axis shape as self.
# </pre>

# %%
df['SpeciesArea'] = df['SepalWidth'].transform(lambda x: x**2*np.pi)
df.sample(5)
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth             Name  \
# 4           5.0         3.6          1.4         0.2      Iris-setosa
# 17          5.1         3.5          1.4         0.3      Iris-setosa
# 62          6.0         2.2          4.0         1.0  Iris-versicolor
# 19          5.1         3.8          1.5         0.3      Iris-setosa
# 37          4.9         3.1          1.5         0.1      Iris-setosa
#
#     SpeciesArea
# 4     40.715041
# 17    38.484510
# 62    15.205308
# 19    45.364598
# 37    30.190705

# %% [markdown]
# ## 29. DataFrame rename
# <pre>Create a df2 to record 'PetalLength' mean of each species
# Rename the 'PetalLength' in df2 to 'PetalLengthMedian'
# Desired Output:
# Name	        PetalLengthMean
# Iris-setosa	    1.50
# Iris-versicolor	4.35
# Iris-virginica	 5.55
# </pre>

# %% [markdown]
# ### 1. 個 table 我要兩個colnum, 1. Name, 2. PetalLength ----> df[['Name','PetalLength']]
# ### 2. 同名嘅出一次俾我 ----> .groupby('Name')
# ### 3. 我要data數嘅median ----> .agg('median')

# %%
df2 = df[['Name','PetalLength']].groupby('Name').agg('median')
df2
# Out:
#                  PetalLength
# Name
# Iris-setosa             1.50
# Iris-versicolor         4.35
# Iris-virginica          5.55

# %% [markdown]
# ### rename , 改名，將剛剛計完嘅，PetalLength 改做 PetalLengthMedian

# %%
df2 = df2.rename(columns={'PetalLength':'PetalLengthMedian'})
df2
# Out:
#                  PetalLengthMedian
# Name
# Iris-setosa                   1.50
# Iris-versicolor               4.35
# Iris-virginica                5.55

# %% [markdown]
# ## 30. Merge 2 DataFrame by key
# <pre>Merge DataFrame or named Series objects with a database-style join.
# Requirement:
# Merge df and df2 with key 'Name'
# </pre>

# %%
df = df.merge(df2, left_on='Name', right_on='Name')
df.sample(5)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth             Name  \
# 20           5.4         3.4          1.7         0.2      Iris-setosa
# 21           5.1         3.7          1.5         0.4      Iris-setosa
# 128          6.4         2.8          5.6         2.1   Iris-virginica
# 146          6.3         2.5          5.0         1.9   Iris-virginica
# 79           5.7         2.6          3.5         1.0  Iris-versicolor
#
#      PetalLengthMedian
# 20                1.50
# 21                1.50
# 128               5.55
# 146               5.55
# 79                4.35

# %% [markdown]
# ![8684187baa4f4fcc95f9bdc2b4ee5868.png](attachment:8684187baa4f4fcc95f9bdc2b4ee5868.png)

# %%
# More test
df1 = pd.read_csv('iris.csv')
pd.merge(df, df2, on="Name", how="outer")
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name  \
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
#      PetalLengthMedian_x  PetalLengthMedian_y
# 0                   1.50                 1.50
# 1                   1.50                 1.50
# 2                   1.50                 1.50
# 3                   1.50                 1.50
# 4                   1.50                 1.50
# ..                   ...                  ...
# 145                 5.55                 5.55
# 146                 5.55                 5.55
# 147                 5.55                 5.55
# 148                 5.55                 5.55
# 149                 5.55                 5.55
#
# [150 rows x 7 columns]

# %%
pd.merge(df1, df2, on="Name", how="left")
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name  \
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
#      PetalLengthMedian
# 0                 1.50
# 1                 1.50
# 2                 1.50
# 3                 1.50
# 4                 1.50
# ..                 ...
# 145               5.55
# 146               5.55
# 147               5.55
# 148               5.55
# 149               5.55
#
# [150 rows x 6 columns]

# %% [markdown]
# ## 31. Plot with Pandas DF
# Plot with Pandas DF. The default plotting backend of Pandas is Matplotlib. You may plot simple graph with DF without import Matplotlib or other visualisation tools.

# %%
df[['SepalLength','PetalLength']].plot.hist(bins=12, alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot

# %%
df.plot.scatter(x='SepalLength', y='SepalWidth')
# Out:
# <Axes: xlabel='SepalLength', ylabel='SepalWidth'>

# %%
df[['SepalWidth','PetalWidth']].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## 32. Save DataFrame

# %%
df.to_html('test.html')

# %%
df.to_csv('test.csv')

# %%
df.to_markdown('test.md')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.12/lib/python3.11/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~/.pyenv/versions/3.11.12/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'tabulate'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.to_markdown('test.md')
#
# File ~/.pyenv/versions/3.11.12/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.12/lib/python3.11/site-packages/pandas/core/frame.py:2983, in DataFrame.to_markdown(self, buf, mode, index, storage_options, **kwargs)
#    2981 kwargs.setdefault("tablefmt", "pipe")
#    2982 kwargs.setdefault("showindex", index)
# -> 2983 tabulate = import_optional_dependency("tabulate")
#    2984 result = tabulate.tabulate(self, **kwargs)
#    2985 if buf is None:
#
# File ~/.pyenv/versions/3.11.12/lib/python3.11/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'tabulate'.  Use pip or conda to install tabulate.

# %% [markdown]
# ## 33. Pandas dtype
# <pre>The default Pandas dtype:
# real number dtype is float64
# Int number dtype is int64
# String is object</pre>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SepalLength        150 non-null    float64
#  1   SepalWidth         150 non-null    float64
#  2   PetalLength        150 non-null    float64
#  3   PetalWidth         150 non-null    float64
#  4   Name               150 non-null    object
#  5   PetalLengthMedian  150 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 7.2+ KB

# %%
d = {'col1': [1, 2], 
     'col2': [3., 4.], 
     'col3': ['user1', 'user2']}
df3 = pd.DataFrame(data=d)
df3.dtypes
# Out:
# col1      int64
# col2    float64
# col3     object
# dtype: object

# %%
d = {'col1': np.array([1,2]), 
     'col2': np.array([3.,4.]), 
     'col3': ['user1', 'user2']}
df3 = pd.DataFrame(data=d)
df3.dtypes
# Out:
# col1      int64
# col2    float64
# col3     object
# dtype: object

# %%
df3.memory_usage()
# Out:
# Index    128
# col1      16
# col2      16
# col3      16
# dtype: int64

# %%
df3.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Columns: 3 entries, col1 to col3
# dtypes: float64(1), int64(1), object(1)
# memory usage: 176.0+ bytes

# %% [markdown]
# ## 34. Check int64 and float64 range

# %%
import sys
sys.maxsize
# Out:
# 9223372036854775807

# %%
type(sys.maxsize)
# Out:
# int

# %%
sys.maxsize == 2**63 - 1
# Out:
# True

# %%
2**63 - 1
# Out:
# 9223372036854775807

# %% [markdown]
# ## 35. Change numeric column Dtype to float16

# %%
# Before trim down the dtype, memory usage: 9.4+ KB
df.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Columns: 7 entries, SepalLength to PetalLengthMedian
# dtypes: float64(6), object(1)
# memory usage: 9.4+ KB

# %%
# Trim all numeric column to float16
df[['SepalLength','SepalWidth','PetalLength','PetalWidth','SpeciesArea']] = df[
    ['SepalLength','SepalWidth','PetalLength','PetalWidth','SpeciesArea']].astype(np.float16)

# %%
# After trim down the dtype, memory usage: 5.0+ KB
df.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Columns: 7 entries, SepalLength to PetalLengthMedian
# dtypes: float16(5), float64(1), object(1)
# memory usage: 5.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SepalLength        150 non-null    float16
#  1   SepalWidth         150 non-null    float16
#  2   PetalLength        150 non-null    float16
#  3   PetalWidth         150 non-null    float16
#  4   Name               150 non-null    object
#  5   SpeciesArea        150 non-null    float16
#  6   PetalLengthMedian  150 non-null    float64
# dtypes: float16(5), float64(1), object(1)
# memory usage: 5.0+ KB

# %%
# Max of float16
np.finfo(np.float16).max
# Out:
# 65500.0

# %%
# Min of float16
np.finfo(np.float16).min
# Out:
# -65500.0

# %%
# Max of int64
np.iinfo(np.int64).max
# Out:
# 9223372036854775807

# %%
# Min of int64
np.iinfo(np.int64).min
# Out:
# -9223372036854775808

# %%
# Max of uint64
np.iinfo(np.uint64).max
# Out:
# 18446744073709551615

# %%
# Min of uint64
np.iinfo(np.uint64).min
# Out:
# 0

# %% [markdown]
# ## 36. Calculates the difference of a DataFrame element compared with another element in the DataFrame

# %%
df[['SepalLength','PetalLength']]
# Out:
#      SepalLength  PetalLength
# 0            5.1          1.4
# 1            4.9          1.4
# 2            4.7          1.3
# 3            4.6          1.5
# 4            5.0          1.4
# ..           ...          ...
# 145          6.7          5.2
# 146          6.3          5.0
# 147          6.5          5.2
# 148          6.2          5.4
# 149          5.9          5.1
#
# [150 rows x 2 columns]

# %%
df[['SepalLength','PetalLength']].diff(axis=1)
# Out:
#      SepalLength  PetalLength
# 0            NaN    -3.701172
# 1            NaN    -3.498047
# 2            NaN    -3.398438
# 3            NaN    -3.101562
# 4            NaN    -3.599609
# ..           ...          ...
# 145          NaN    -1.500000
# 146          NaN    -1.300781
# 147          NaN    -1.300781
# 148          NaN    -0.800781
# 149          NaN    -0.796875
#
# [150 rows x 2 columns]

# %%
df[['SepalLength','PetalLength']].diff()
# Out:
#      SepalLength  PetalLength
# 0            NaN          NaN
# 1      -0.203125     0.000000
# 2      -0.199219    -0.100586
# 3      -0.097656     0.200195
# 4       0.398438    -0.099609
# ..           ...          ...
# 145     0.000000    -0.500000
# 146    -0.398438    -0.199219
# 147     0.199219     0.199219
# 148    -0.300781     0.199219
# 149    -0.300781    -0.296875
#
# [150 rows x 2 columns]

# %% [markdown]
# ## 37. Get item from object for given key
# <pre>Given a wather DF, use .get() to retrieve windspeed value on '2020-02-13'
# weather = pd.DataFrame(
#     [   [24.3, 75.7, "high"],
#         [31, 87.8, "high"],
#         [22, 71.6, "medium"],
#         [35, 95, "medium"],
#     ],
#     columns=["temp_celsius", "temp_fahrenheit", "windspeed"],
#     index=pd.date_range(start="2020-02-12", end="2020-02-15", freq="D"),
# )</pre>

# %%
weather = pd.DataFrame(
    [   [24.3, 75.7, "high"],
        [31, 87.8, "high"],
        [22, 71.6, "medium"],
        [35, 95, "medium"],
    ],
    columns=["temp_celsius", "temp_fahrenheit", "windspeed"],
    index=pd.date_range(start="2020-02-12", end="2020-02-15", freq="D"),
)
weather
# Out:
#             temp_celsius  temp_fahrenheit windspeed
# 2020-02-12          24.3             75.7      high
# 2020-02-13          31.0             87.8      high
# 2020-02-14          22.0             71.6    medium
# 2020-02-15          35.0             95.0    medium

# %%
weather['windspeed'].get('2020-02-13')
# Out:
# 'high'

# %%
weather['windspeed'].get('2023-05-20', default="No found")
# Out:
# 'No found'

# %% [markdown]
# ## 38. DataFrame representation

# %%
# Return a tuple representing the dimensionality of the DataFrame
weather.shape
# Out:
# (4, 3)

# %%
# Return an int representing the number of elements in this object.
weather.size
# Out:
# 12

# %%
# Return an int representing the number of axes / array dimensions
# Return 1 if Series. Otherwise return 2 if DataFrame.
weather.ndim
# Out:
# 2

# %% [markdown]
# ## 39. DataFrame representation

# %%
# Return a list representing the axes of the DataFrame.
weather.axes
# Out:
# [DatetimeIndex(['2020-02-12', '2020-02-13', '2020-02-14', '2020-02-15'], dtype='datetime64[ns]', freq='D'),
#  Index(['temp_celsius', 'temp_fahrenheit', 'windspeed'], dtype='object')]

# %%
# Return a Numpy representation of the DataFrame
weather.values
# Out:
# array([[24.3, 75.7, 'high'],
#        [31.0, 87.8, 'high'],
#        [22.0, 71.6, 'medium'],
#        [35.0, 95.0, 'medium']], dtype=object)

# %%
# The column labels of the DataFrame
weather.columns
# Out:
# Index(['temp_celsius', 'temp_fahrenheit', 'windspeed'], dtype='object')

# %% [markdown]
# ## 40. Insert new column with values (add)

# %%
weather.insert(3,'sunny', [False, True, False, True])   #insert, index, 3, name: 'Sunny', [data]
weather
# Out:
#             temp_celsius  temp_fahrenheit windspeed  sunny
# 2020-02-12          24.3             75.7      high  False
# 2020-02-13          31.0             87.8      high   True
# 2020-02-14          22.0             71.6    medium  False
# 2020-02-15          35.0             95.0    medium   True

# %% [markdown]
# ## 41. Insert new data row
# <pre>Requirement:
# Add '2020-02-16' as datetime index, and row data
# [31.0, 87.8, 'medium', True] to DF weather.
# </pre>

# %%
weather.loc[pd.to_datetime('2020-02-16',format='%Y-%m-%d')] = [31.0, 87.8, 'medium', True]
weather
# Out:
#             temp_celsius  temp_fahrenheit windspeed  sunny
# 2020-02-12          24.3             75.7      high  False
# 2020-02-13          31.0             87.8      high   True
# 2020-02-14          22.0             71.6    medium  False
# 2020-02-15          35.0             95.0    medium   True
# 2020-02-16          31.0             87.8    medium   True

# %% [markdown]
# ## 42. Change Datetime indext to another type

# %%
weather.index = weather.index.strftime('%Y-%m-%d 00:00:00')

# %%
weather
# Out:
#                      temp_celsius  temp_fahrenheit windspeed  sunny
# 2020-02-12 00:00:00          24.3             75.7      high  False
# 2020-02-13 00:00:00          31.0             87.8      high   True
# 2020-02-14 00:00:00          22.0             71.6    medium  False
# 2020-02-15 00:00:00          35.0             95.0    medium   True
# 2020-02-16 00:00:00          31.0             87.8    medium   True

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 2020-02-12 00:00:00 to 2020-02-16 00:00:00
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   temp_celsius     5 non-null      float64
#  1   temp_fahrenheit  5 non-null      float64
#  2   windspeed        5 non-null      object
#  3   sunny            5 non-null      bool
# dtypes: bool(1), float64(2), object(1)
# memory usage: 165.0+ bytes

# %% [markdown]
# ## 43. Time Delta
# Represents a duration, the difference between two dates or times

# %%
from datetime import datetime, timedelta
today = datetime.now()
str(today)
# Out:
# '2025-12-23 14:58:47.439615'

# %%
# 1000 days later, will be
str(today + timedelta(days = 1000))
# Out:
# '2028-09-18 14:58:47.439615'

# %%
(today + timedelta(days = 1000)).strftime('%Y-%m-%d')
# Out:
# '2028-09-18'

# %% [markdown]
# ## 44. PD.date_range
# Return a fixed frequency DatetimeIndex.

# %%
pd.date_range(start='2023-01-01', periods=8)
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(end='2023-01-01', periods=8)
# Out:
# DatetimeIndex(['2022-12-25', '2022-12-26', '2022-12-27', '2022-12-28',
#                '2022-12-29', '2022-12-30', '2022-12-31', '2023-01-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2023-01-01', end='2023-07-01', periods=7)
# Out:
# DatetimeIndex(['2023-01-01 00:00:00', '2023-01-31 04:00:00',
#                '2023-03-02 08:00:00', '2023-04-01 12:00:00',
#                '2023-05-01 16:00:00', '2023-05-31 20:00:00',
#                '2023-07-01 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## 45. Convert Unix time (Epoch time) to datetime

# %%
import time
epoch = time.time()
epoch
# Out:
# 1766473169.097035

# %%
local_time = time.ctime(epoch)
local_time
# Out:
# 'Tue Dec 23 14:59:29 2025'

# %%
# Structure time
time.localtime()
# Out:
# time.struct_time(tm_year=2025, tm_mon=12, tm_mday=23, tm_hour=15, tm_min=1, tm_sec=10, tm_wday=1, tm_yday=357, tm_isdst=0)

# %%
from datetime import datetime
datetime.fromtimestamp(epoch).strftime( "%d-%m-%Y %H:%M:%S" )
# Out:
# '23-12-2025 14:59:29'
