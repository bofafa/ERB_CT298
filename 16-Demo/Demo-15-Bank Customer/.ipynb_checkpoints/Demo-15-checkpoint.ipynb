# %%
# pip install -U seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import accuracy_score
from sklearn.inspection import permutation_importance

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
data = pd.read_csv('CustomerRecords.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# 1        112542.58       0         1                   3   DIAMOND
# 2        113931.57       1         1                   3   DIAMOND
# 3         93826.63       0         0                   5      GOLD
# 4         79084.10       0         0                   5      GOLD
#
#    Point Earned
# 0           464
# 1           456
# 2           377
# 3           350
# 4           425

# %%
data.shape
# Out:
# (10000, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
#  15  Satisfaction Score  10000 non-null  int64
#  16  Card Type           10000 non-null  object
#  17  Point Earned        10000 non-null  int64
# dtypes: float64(2), int64(12), object(4)
# memory usage: 1.4+ MB

# %%
data.describe(include='O')
# Out:
#        Surname Geography Gender Card Type
# count    10000     10000  10000     10000
# unique    2932         3      2         4
# top      Smith    France   Male   DIAMOND
# freq        32      5014   5457      2507

# %%
data['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
data['Card Type'].unique()
# Out:
# array(['DIAMOND', 'GOLD', 'SILVER', 'PLATINUM'], dtype=object)

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited      Complain  Satisfaction Score  \
# count     10000.000000  10000.000000  10000.000000        10000.000000
# mean     100090.239881      0.203800      0.204400            3.013800
# std       57510.492818      0.402842      0.403283            1.405919
# min          11.580000      0.000000      0.000000            1.000000
# 25%       51002.110000      0.000000      0.000000            2.000000
# 50%      100193.915000      0.000000      0.000000            3.000000
# 75%      149388.247500      0.000000      0.000000            4.000000
# max      199992.480000      1.000000      1.000000            5.000000
#
#        Point Earned
# count  10000.000000
# mean     606.515100
# std      225.924839
# min      119.000000
# 25%      410.000000
# 50%      605.000000
# 75%      801.000000
# max     1000.000000

# %%
data.head(3).T
# Out:
#                             0          1          2
# RowNumber                   1          2          3
# CustomerId           15634602   15647311   15619304
# Surname              Hargrave       Hill       Onio
# CreditScore               619        608        502
# Geography              France      Spain     France
# Gender                 Female     Female     Female
# Age                        42         41         42
# Tenure                      2          1          8
# Balance                   0.0   83807.86   159660.8
# NumOfProducts               1          1          3
# HasCrCard                   1          0          1
# IsActiveMember              1          1          0
# EstimatedSalary     101348.88  112542.58  113931.57
# Exited                      1          0          1
# Complain                    1          1          1
# Satisfaction Score          2          3          3
# Card Type             DIAMOND    DIAMOND    DIAMOND
# Point Earned              464        456        377

# %%
data.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize=(6, 6))
churn_counts = data['Exited'].value_counts()
plt.pie(churn_counts, labels=['Retained', 'Churned'], autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Churn Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', hue=data['Exited'].astype(str), data=data)  # hue='Exited'
plt.title('Churn by Gender')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Geography', hue=data['Exited'].astype(str), data=data)
plt.title('Churn by Geography')
plt.show()

# %%
data['AgeGroup'] = pd.cut(data['Age'], bins=[0, 30, 40, 50, 60, np.inf], 
                          labels=['<30', '30-40', '40-50', '50-60', '60+'])
plt.figure(figsize=(8, 6))
sns.countplot(x='AgeGroup', hue='Exited', data=data, palette=['tab:orange', 'tab:blue'])
plt.title('Churn by Age Group')
plt.show()

# %% [markdown]
# ## Churn rate by gender

# %%
churn_rate_gender = data.groupby('Gender')['Exited'].mean()
print(churn_rate_gender)
# Out:
# Gender
# Female    0.250715
# Male      0.164743
# Name: Exited, dtype: float64

# %% [markdown]
# ## Churn rate by geography

# %%
churn_rate_geography = data.groupby('Geography')['Exited'].mean()
print(churn_rate_geography)
# Out:
# Geography
# France     0.161747
# Germany    0.324432
# Spain      0.166734
# Name: Exited, dtype: float64

# %% [markdown]
# ## Churn rate by age group

# %%
churn_rate_age = data.groupby('AgeGroup', observed=True)['Exited'].mean()
print(churn_rate_age)
# Out:
# AgeGroup
# <30      0.075203
# 30-40    0.121096
# 40-50    0.339655
# 50-60    0.562108
# 60+      0.247845
# Name: Exited, dtype: float64

# %% [markdown]
# ## Churn by Number of Products

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='NumOfProducts', hue=data['Exited'].astype(str), data=data)
plt.title('Churn by Number of Products')
plt.show()

# %% [markdown]
# ## Churn by Credit Card

# %%
data.groupby('HasCrCard')['Exited'].mean()
# Out:
# HasCrCard
# 0    0.208149
# 1    0.201984
# Name: Exited, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='HasCrCard', hue=data['Exited'].astype(str), data=data, palette=['tab:orange', 'tab:blue'])
plt.title('Churn by Credit Card')
plt.show()

# %% [markdown]
# ## Churn by Activity Status

# %%
data.groupby('IsActiveMember')['Exited'].mean()
# Out:
# IsActiveMember
# 0    0.268715
# 1    0.142691
# Name: Exited, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='IsActiveMember', hue=data['Exited'].astype(str), data=data)
plt.title('Churn by Activity Status')
plt.show()

# %% [markdown]
# ## Churn by Balance

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Exited', y='Balance', data=data)
plt.title('Churn by Balance')
plt.show()

# %% [markdown]
# ## Churn by Complain

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Complain', hue=data['Exited'].astype(str), data=data, palette=['tab:orange', 'tab:blue'])
plt.title('Churn by Complain')
plt.show()

# %% [markdown]
# # Create Model for prediction

# %%
# Drop unnecessarry column
data.drop(columns=["RowNumber", "CustomerId", "Surname"], inplace=True)

# %%
data.head(3)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
#
#    Satisfaction Score Card Type  Point Earned AgeGroup
# 0                   2   DIAMOND           464    40-50
# 1                   3   DIAMOND           456    40-50
# 2                   3   DIAMOND           377    40-50

# %% [markdown]
# ## Identify features (without 'Exited')

# %%
feature = ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
       'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
        'Complain', 'Satisfaction Score', 'Card Type', 'Point Earned',
       'AgeGroup']

# %% [markdown]
# ## Categorical Encoding

# %%
cat_cols = ["Geography", "Gender", "Card Type", "AgeGroup"]
enc = OrdinalEncoder()
data[cat_cols] = enc.fit_transform(data[cat_cols])

# %%
data[cat_cols].nunique()
# Out:
# Geography    3
# Gender       2
# Card Type    4
# AgeGroup     5
# dtype: int64

# %%
data[cat_cols].sample(3)
# Out:
#       Geography  Gender  Card Type  AgeGroup
# 2327        0.0     1.0        2.0       4.0
# 2931        1.0     0.0        2.0       0.0
# 86          2.0     1.0        3.0       4.0

# %%
data[cat_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Geography  10000 non-null  float64
#  1   Gender     10000 non-null  float64
#  2   Card Type  10000 non-null  float64
#  3   AgeGroup   10000 non-null  float64
# dtypes: float64(4)
# memory usage: 312.6 KB

# %%
data.head(3).T
# Out:
#                             0          1          2
# CreditScore            619.00     608.00     502.00
# Geography                0.00       2.00       0.00
# Gender                   0.00       0.00       0.00
# Age                     42.00      41.00      42.00
# Tenure                   2.00       1.00       8.00
# Balance                  0.00   83807.86  159660.80
# NumOfProducts            1.00       1.00       3.00
# HasCrCard                1.00       0.00       1.00
# IsActiveMember           1.00       1.00       0.00
# EstimatedSalary     101348.88  112542.58  113931.57
# Exited                   1.00       0.00       1.00
# Complain                 1.00       1.00       1.00
# Satisfaction Score       2.00       3.00       3.00
# Card Type                0.00       0.00       0.00
# Point Earned           464.00     456.00     377.00
# AgeGroup                 1.00       1.00       1.00

# %% [markdown]
# ## Split Train & Test

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop("Exited", axis=1), 
                                    data["Exited"], test_size=0.20, random_state=42)

# %% [markdown]
# ## Train and test model

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
print("Accuracy on test data: {:.2f}".format(clf.score(X_test, y_test)))
# Out:
# Accuracy on test data: 1.00

# %% [markdown]
# ## Correlation of features and target

# %%
data.corrwith(data['Exited']).sort_values(ascending=False)
# Out:
# Exited                1.000000
# Complain              0.995693
# Age                   0.285296
# Balance               0.118577
# Geography             0.035712
# EstimatedSalary       0.012490
# Point Earned         -0.004628
# Satisfaction Score   -0.005849
# HasCrCard            -0.006976
# AgeGroup             -0.010406
# Card Type            -0.010861
# Tenure               -0.013656
# CreditScore          -0.026771
# NumOfProducts        -0.047611
# Gender               -0.106267
# IsActiveMember       -0.156356
# dtype: float64

# %% [markdown]
# ## Justify visual with model result

# %%
result = permutation_importance(clf, X_train, y_train, n_repeats=10, random_state=42)
perm_sorted_idx = result.importances_mean.argsort()

tree_importance_sorted_idx = np.argsort(clf.feature_importances_)
tree_indices = np.arange(0, len(clf.feature_importances_)) + 0.5

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
ax1.barh(tree_indices, clf.feature_importances_[tree_importance_sorted_idx], height=0.7)
ax1.set_yticks(tree_indices)
ax1.set_yticklabels(X_train.columns[tree_importance_sorted_idx])
ax1.set_ylim((0, len(clf.feature_importances_)))
ax2.boxplot(
    result.importances[perm_sorted_idx].T,
    vert=False,
    labels=X_train.columns[perm_sorted_idx],
)
fig.tight_layout()
plt.show()
