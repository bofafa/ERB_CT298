# %%
# pip install folium

# %%
# pip install geopandas

# %%
import numpy as np 
import pandas as pd

import folium
from folium import plugins
import geopandas as gpd
import branca

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from textwrap import wrap
from matplotlib.lines import Line2D
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

from scipy import stats
from scipy.stats import ttest_ind

plt.rcParams["font.family"] = "DejaVu Sans"

background_color='#F5F4EF'

HEADER = '\033[95m'
OKBLUE = '\033[94m'
OKCYAN = '\033[96m'
OKGREEN = '\033[92m'
WARNING = '\033[93m'
FAIL = '\033[91m'
ENDC = '\033[0m'
BOLD = '\033[1m'
UNDERLINE = '\033[4m'

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Print colored text
# https://stackoverflow.com/questions/287871/how-to-print-colored-text-to-the-terminal
# ### Includes other color options

# %%
class color_font:
    S = BOLD + OKBLUE +  UNDERLINE   #S = Start
    E = ENDC #E = End
    
print(color_font.S+"Datasets & Libraries"+color_font.E)
# Out:
# Datasets & Libraries

# %% [markdown]
# ## Import dataset

# %%
population = pd.read_csv('Olympic/population_by_country_2020.csv')
regions = pd.read_csv('Olympic/120Yrs-Olympic-History/noc_regions.csv')

df = pd.read_csv('Olympic/120Yrs-Olympic-History/athlete_events.csv')
df_21 = pd.read_csv('Olympic/2021-Medal/Tokyo 2021 dataset.csv')
df_21_full = pd.read_csv('Olympic/2021-Medal/Tokyo 2021 dataset.csv')

# For geographic plotting
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes = f'{url}/world-countries.json'

# %%
df.sample(3)
# Out:
#            ID                Name Sex   Age  Height  Weight         Team  NOC
# 65483   33516  Brand "Bram" Evers   M  21.0     NaN     NaN  Netherlands  NED  \
# 184160  92558        Pierre Pcher   M   NaN     NaN     NaN      Belgium  BEL
# 95793   48487      Yvette Higgins   F  22.0   173.0    73.0    Australia  AUS
#
#               Games  Year  Season       City       Sport
# 65483   1908 Summer  1908  Summer     London   Athletics  \
# 184160  1928 Summer  1928  Summer  Amsterdam     Fencing
# 95793   2000 Summer  2000  Summer     Sydney  Water Polo
#
#                                 Event Medal
# 65483      Athletics Men's 800 metres   NaN
# 184160       Fencing Men's Foil, Team   NaN
# 95793   Water Polo Women's Water Polo  Gold

# %%
fig, ax = plt.subplots(figsize=(4, 5), facecolor=background_color)

temp = df_21_full[:15].sort_values(by='Total')
my_range=range(1,len(df_21_full[:15]['Team/NOC'])+1)

ax.set_facecolor(background_color)

plt.hlines(y=my_range, xmin=0, xmax=temp['Total'], color='gray')
plt.plot(temp['Total'], my_range, "o",markersize=10, color='#244747')
plt.plot(temp['Total'][2], my_range[10], "o",markersize=20,color='#B73832')

Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

ax.tick_params(axis=u'both', which=u'both',length=0)
ax.set_xlabel("Total Medals",fontfamily='DejaVu Sans',loc='left',color='gray')
ax.set_axisbelow(True)

for s in ['top','right','bottom','left']:
    ax.spines[s].set_visible(False)
    
ax.text(-90,Yend+2.3, 'Olympic Total Medals by Country: Tokyo 2021', fontsize=15,
                                fontweight='bold',fontfamily='serif',color='#323232')
ax.text(-90,Yend+1.1, 'Japan hosted the games for the second time', fontsize=10,
                            fontweight='bold',color='#B73832')
#ax.text(-100,Yend+1, 'Not Hosting', fontsize=10,fontweight='bold',fontfamily='sansserif',color='#244747')

plt.yticks(my_range, temp['Team/NOC'])
plt.xlabel('')

ax.annotate(temp['Total'][2], xy=(54.86,10.95), va = 'center', ha='left',fontweight='light', 
            fontfamily='monospace',fontsize=10, color='white',rotation=0)
plt.show()

# %% [markdown]
# ## Top 15 Medal Countries

# %%
df_21_full[['Rank','Team/NOC','Bronze Medal','Silver Medal','Gold Medal','Total']].iloc[:15]
# Out:
#     Rank                    Team/NOC  Bronze Medal  Silver Medal  Gold Medal
# 0      1    United States of America            33            41          39  \
# 1      2  People's Republic of China            18            32          38
# 2      3                       Japan            17            14          27
# 3      4               Great Britain            22            21          22
# 4      5                         ROC            23            28          20
# 5      6                   Australia            22             7          17
# 6      7                 Netherlands            14            12          10
# 7      8                      France            11            12          10
# 8      9                     Germany            16            11          10
# 9     10                       Italy            20            10          10
# 10    11                      Canada            11             6           7
# 11    12                      Brazil             8             6           7
# 12    13                 New Zealand             7             6           7
# 13    14                        Cuba             5             3           7
# 14    15                     Hungary             7             7           6
#
#     Total
# 0     113
# 1      88
# 2      58
# 3      65
# 4      71
# 5      46
# 6      36
# 7      33
# 8      37
# 9      40
# 10     24
# 11     21
# 12     20
# 13     15
# 14     20

# %%
def highlight(nation):
    if nation['Team/NOC'] == 'Japan':
        return ['background-color: #f3f2f1']*6
    else:
        return ['background-color: white']*6

df_21_full[['Rank','Team/NOC','Bronze Medal','Silver Medal','Gold Medal','Total']]\
.iloc[:15].style.set_caption('Medals by Country: Summer Olympic Games sorted by Gold Medals [Top 15]')\
.bar(subset=['Gold Medal'], color='#f0c05a')\
.bar(subset=['Silver Medal'], color='Lightgray')\
.bar(subset=['Bronze Medal'], color='#a97142')\
.hide(axis="index").apply(highlight, axis=1)
# Out:
# <style type="text/css">
# #T_2cd26_row0_col0, #T_2cd26_row0_col1, #T_2cd26_row0_col5, #T_2cd26_row1_col0, #T_2cd26_row1_col1, #T_2cd26_row1_col5, #T_2cd26_row3_col0, #T_2cd26_row3_col1, #T_2cd26_row3_col5, #T_2cd26_row4_col0, #T_2cd26_row4_col1, #T_2cd26_row4_col5, #T_2cd26_row5_col0, #T_2cd26_row5_col1, #T_2cd26_row5_col5, #T_2cd26_row6_col0, #T_2cd26_row6_col1, #T_2cd26_row6_col5, #T_2cd26_row7_col0, #T_2cd26_row7_col1, #T_2cd26_row7_col5, #T_2cd26_row8_col0, #T_2cd26_row8_col1, #T_2cd26_row8_col5, #T_2cd26_row9_col0, #T_2cd26_row9_col1, #T_2cd26_row9_col5, #T_2cd26_row10_col0, #T_2cd26_row10_col1, #T_2cd26_row10_col5, #T_2cd26_row11_col0, #T_2cd26_row11_col1, #T_2cd26_row11_col5, #T_2cd26_row12_col0, #T_2cd26_row12_col1, #T_2cd26_row12_col5, #T_2cd26_row13_col0, #T_2cd26_row13_col1, #T_2cd26_row13_col5, #T_2cd26_row14_col0, #T_2cd26_row14_col1, #T_2cd26_row14_col5 {
#   background-color: white;
# }
# #T_2cd26_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 100.0%, transparent 100.0%);
#   background-color: white;
# }
# #T_2cd26_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 100.0%, transparent 100.0%);
#   background-color: white;
# }
# #T_2cd26_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 100.0%, transparent 100.0%);
#   background-color: white;
# }
# #T_2cd26_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 54.5%, transparent 54.5%);
#   background-color: white;
# }
# #T_2cd26_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 78.0%, transparent 78.0%);
#   background-color: white;
# }
# #T_2cd26_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 97.4%, transparent 97.4%);
#   background-color: white;
# }
# #T_2cd26_row2_col0, #T_2cd26_row2_col1, #T_2cd26_row2_col5 {
#   background-color: #f3f2f1;
# }
# #T_2cd26_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 51.5%, transparent 51.5%);
#   background-color: #f3f2f1;
# }
# #T_2cd26_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 34.1%, transparent 34.1%);
#   background-color: #f3f2f1;
# }
# #T_2cd26_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 69.2%, transparent 69.2%);
#   background-color: #f3f2f1;
# }
# #T_2cd26_row3_col2, #T_2cd26_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 66.7%, transparent 66.7%);
#   background-color: white;
# }
# #T_2cd26_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 51.2%, transparent 51.2%);
#   background-color: white;
# }
# #T_2cd26_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 56.4%, transparent 56.4%);
#   background-color: white;
# }
# #T_2cd26_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 69.7%, transparent 69.7%);
#   background-color: white;
# }
# #T_2cd26_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 68.3%, transparent 68.3%);
#   background-color: white;
# }
# #T_2cd26_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 51.3%, transparent 51.3%);
#   background-color: white;
# }
# #T_2cd26_row5_col3, #T_2cd26_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 17.1%, transparent 17.1%);
#   background-color: white;
# }
# #T_2cd26_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 43.6%, transparent 43.6%);
#   background-color: white;
# }
# #T_2cd26_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 42.4%, transparent 42.4%);
#   background-color: white;
# }
# #T_2cd26_row6_col3, #T_2cd26_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 29.3%, transparent 29.3%);
#   background-color: white;
# }
# #T_2cd26_row6_col4, #T_2cd26_row7_col4, #T_2cd26_row8_col4, #T_2cd26_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 25.6%, transparent 25.6%);
#   background-color: white;
# }
# #T_2cd26_row7_col2, #T_2cd26_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 33.3%, transparent 33.3%);
#   background-color: white;
# }
# #T_2cd26_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 48.5%, transparent 48.5%);
#   background-color: white;
# }
# #T_2cd26_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 26.8%, transparent 26.8%);
#   background-color: white;
# }
# #T_2cd26_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 60.6%, transparent 60.6%);
#   background-color: white;
# }
# #T_2cd26_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 24.4%, transparent 24.4%);
#   background-color: white;
# }
# #T_2cd26_row10_col3, #T_2cd26_row11_col3, #T_2cd26_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 14.6%, transparent 14.6%);
#   background-color: white;
# }
# #T_2cd26_row10_col4, #T_2cd26_row11_col4, #T_2cd26_row12_col4, #T_2cd26_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 17.9%, transparent 17.9%);
#   background-color: white;
# }
# #T_2cd26_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 24.2%, transparent 24.2%);
#   background-color: white;
# }
# #T_2cd26_row12_col2, #T_2cd26_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 21.2%, transparent 21.2%);
#   background-color: white;
# }
# #T_2cd26_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 15.2%, transparent 15.2%);
#   background-color: white;
# }
# #T_2cd26_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 7.3%, transparent 7.3%);
#   background-color: white;
# }
# #T_2cd26_row14_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 15.4%, transparent 15.4%);
#   background-color: white;
# }
# </style>
# <table id="T_2cd26">
#   <caption>Medals by Country: Summer Olympic Games sorted by Gold Medals [Top 15]</caption>
#   <thead>
#     <tr>
#       <th id="T_2cd26_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_2cd26_level0_col1" class="col_heading level0 col1" >Team/NOC</th>
#       <th id="T_2cd26_level0_col2" class="col_heading level0 col2" >Bronze Medal</th>
#       <th id="T_2cd26_level0_col3" class="col_heading level0 col3" >Silver Medal</th>
#       <th id="T_2cd26_level0_col4" class="col_heading level0 col4" >Gold Medal</th>
#       <th id="T_2cd26_level0_col5" class="col_heading level0 col5" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2cd26_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_2cd26_row0_col1" class="data row0 col1" >United States of America</td>
#       <td id="T_2cd26_row0_col2" class="data row0 col2" >33</td>
#       <td id="T_2cd26_row0_col3" class="data row0 col3" >41</td>
#       <td id="T_2cd26_row0_col4" class="data row0 col4" >39</td>
#       <td id="T_2cd26_row0_col5" class="data row0 col5" >113</td>
#     </tr>
#     <tr>
#       <td id="T_2cd26_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_2cd26_row1_col1" class="data row1 col1" >People's Republic of China</td>
#       <td id="T_2cd26_row1_col2" class="data row1 col2" >18</td>
#       <td id="T_2cd26_row1_col3" class="data row1 col3" >32</td>
#       <td id="T_2cd26_row1_col4" class="data row1 col4" >38</td>
#       <td id="T_2cd26_row1_col5" class="data row1 col5" >88</td>
#     </tr>
#     <tr>
#       <td id="T_2cd26_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_2cd26_row2_col1" class="data row2 col1" >Japan</td>
#       <td id="T_2cd26_row2_col2" class="data row2 col2" >17</td>
#       <td id="T_2cd26_row2_col3" class="data row2 col3" >14</td>
#       <td id="T_2cd26_row2_col4" class="data row2 col4" >27</td>
#       <td id="T_2cd26_row2_col5" class="data row2 col5" >58</td>
#     </tr>
#     <tr>
#       <td id="T_2cd26_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_2cd26_row3_col1" class="data row3 col1" >Great Britain</td>
#       <td id="T_2cd26_row3_col2" class="data row3 col2" >22</td>
#       <td id="T_2cd26_row3_col3" class="data row3 col3" >21</td>
#       <td id="T_2cd26_row3_col4" class="data row3 col4" >22</td>
#       <td id="T_2cd26_r

# %% [markdown]
# ## Geographic visual - showing which countries have hosted the Olympics, and where medals tend to go

# %%
# For geographic plotting
global_polygons = gpd.read_file(country_shapes)
global_polygons.to_file('global_polygons.geojson', driver = 'GeoJSON')

global_polygons.plot(figsize=(10,5)) # test map of the globe

# Tabular
df = pd.merge(df,regions,left_on='NOC',right_on='NOC')
df = df.query('Season == "Summer"') # Only interested in Summer Olympics for this project

# %% [markdown]
# ## Replacing the country name with common values

# %%
df.replace('USA', "United States of America", inplace = True)
df.replace('Tanzania', "United Republic of Tanzania", inplace = True)
df.replace('Democratic Republic of Congo', "Democratic Republic of the Congo", inplace = True)
df.replace('Congo', "Republic of the Congo", inplace = True)
df.replace('Lao', "Laos", inplace = True)
df.replace('Syrian Arab Republic', "Syria", inplace = True)
df.replace('Serbia', "Republic of Serbia", inplace = True)
df.replace('Czechia', "Czech Republic", inplace = True)
df.replace('UAE', "United Arab Emirates", inplace = True)
df.replace('UK', "United Kingdom", inplace = True)

population.replace('United States', "United States of America", inplace = True)
population.replace('Czech Republic (Czechia)', "Czech Republic", inplace = True)
population.replace('DR Congo', "Democratic Republic of the Congo", inplace = True)
population.replace('Serbia', "Republic of Serbia", inplace = True)
population.replace('Tanzania', "United Republic of Tanzania", inplace = True)

df_21_full.replace('Great Britain', "United Kingdom", inplace = True)
df_21_full.replace("People's Republic of China", "China", inplace = True)
df_21_full.replace("ROC", "Russia", inplace = True)

# %% [markdown]
# ## map country to city

# %%
# Function to map country to city. You may try python switch case instead of multiple elif
def host_country(col):
    if col == "Rio de Janeiro":
        return "Brazil"
    elif col == "London":
        return "United Kingdom"
    elif col == "Beijing":
        return  "China"
    elif col == "Athina":
        return  "Greece"
    elif col == "Sydney" or col == "Melbourne":
        return  "Australia"
    elif col == "Atlanta" or col == "Los Angeles" or col == "St. Louis":
        return  "United States of America"
    elif col == "Barcelona":
        return  "Spain"
    elif col == "Seoul":
        return  "South Korea"
    elif col == "Moskva":
        return  "Russia"
    elif col == "Montreal":
        return  "Canada"
    elif col == "Munich" or col == "Berlin":
        return  "Germany"
    elif col == "Mexico City":
        return  "Mexico"
    elif col == "Tokyo":
        return  "Japan"
    elif col == "Roma":
        return  "Italy"
    elif col == "Paris":
        return  "France"
    elif col == "Helsinki":
        return  "Finland"
    elif col == "Amsterdam":
        return  "Netherlands"
    elif col == "Antwerpen":
        return  "Belgium"
    elif col == "Stockholm":
        return  "Sweden"
    else:
        return "Other"

# Applying this function
df['Host_Country'] = df['City'].apply(host_country)

# %% [markdown]
# ## Creat new dataframe containing host nation data

# %%
df_new = df.groupby(['Year','Host_Country','region','Medal']
                   )['Medal'].count().unstack().fillna(0).astype(int).reset_index()

df_new['Is_Host'] = np.where(df_new['Host_Country'] == df_new['region'],1,0)
df_new['Total Medals'] = df_new['Bronze'] + df_new['Silver'] + df_new['Gold']

# %%
# Preparing to add 2021 data to our historic df
df_21_full_refined = df_21_full[['Team/NOC', "Gold Medal", "Silver Medal", "Bronze Medal"]]
df_21_full_refined.loc[df_21_full_refined.index,['Total Medals']] = df_21_full_refined[["Gold Medal", 
                                                            "Silver Medal", "Bronze Medal"]].sum(axis=1)
df_21_full_refined.loc[df_21_full_refined.index,['Year']] = 2021

df_21_full_refined = df_21_full_refined.rename(columns={'Gold Medal':'Gold', 'Silver Medal':'Silver',
                                                            'Bronze Medal':'Bronze'})

df_21_full_refined['Is_Host'] = np.where(df_21_full_refined['Team/NOC'] == 'Japan',1,0)
df_21_full_refined['Host_Country'] = 'Japan'
df_21_full_refined = df_21_full_refined.rename(columns={'Team/NOC':'region'})

# Adding 2021 data to historic
df_new = pd.concat([df_new, df_21_full_refined],axis = 0)

# Removing Russia as many Olympic games were competed in as the Soviet Union, 
# containing several modern day nations
df_new = df_new.query("region != 'Russia' | region != 'ROC'")

# %%
df_21_full_refined.sample()
# Out:
#    region  Gold  Silver  Bronze  Total Medals    Year  Is_Host Host_Country
# 7  France    10      12      11          33.0  2021.0        0        Japan

# %%
df_new.sample()
# Out:
#        Year Host_Country region  Bronze  Gold  Silver  Is_Host  Total Medals
# 186  1928.0  Netherlands  Chile       0     0       1        0           1.0

# %% [markdown]
# ## Medal in all years history

# %%
medals = df.groupby(['region','Medal'])['Medal'].count().unstack().fillna(0).astype(int)

medals['Total'] = medals['Bronze'] + medals['Silver'] + medals['Gold']

medals = medals[['Bronze','Silver','Gold','Total']].sort_values(by='Total', ascending=False)

medals.iloc[:15].style.set_caption('Medals by Country: Summer Olympic Games [Top 15]')\
.bar(subset=['Gold'], color='#f0c05a')\
.bar(subset=['Silver'], color='Lightgray')\
.bar(subset=['Bronze'], color='#a97142')\
.background_gradient(subset=['Total'], cmap='BuGn')
# Out:
# <style type="text/css">
# #T_f01e9_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 100.0%, transparent 100.0%);
# }
# #T_f01e9_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 100.0%, transparent 100.0%);
# }
# #T_f01e9_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 100.0%, transparent 100.0%);
# }
# #T_f01e9_row0_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_f01e9_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 83.0%, transparent 83.0%);
# }
# #T_f01e9_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 73.1%, transparent 73.1%);
# }
# #T_f01e9_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 49.4%, transparent 49.4%);
# }
# #T_f01e9_row1_col3 {
#   background-color: #4cb484;
#   color: #f1f1f1;
# }
# #T_f01e9_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 88.9%, transparent 88.9%);
# }
# #T_f01e9_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 74.0%, transparent 74.0%);
# }
# #T_f01e9_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 43.5%, transparent 43.5%);
# }
# #T_f01e9_row2_col3 {
#   background-color: #4fb688;
#   color: #f1f1f1;
# }
# #T_f01e9_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 51.8%, transparent 51.8%);
# }
# #T_f01e9_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 54.7%, transparent 54.7%);
# }
# #T_f01e9_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 25.7%, transparent 25.7%);
# }
# #T_f01e9_row3_col3 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# #T_f01e9_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 49.0%, transparent 49.0%);
# }
# #T_f01e9_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 43.1%, transparent 43.1%);
# }
# #T_f01e9_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 18.8%, transparent 18.8%);
# }
# #T_f01e9_row4_col3 {
#   background-color: #cfede8;
#   color: #000000;
# }
# #T_f01e9_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 37.9%, transparent 37.9%);
# }
# #T_f01e9_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 35.6%, transparent 35.6%);
# }
# #T_f01e9_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 21.0%, transparent 21.0%);
# }
# #T_f01e9_row5_col3 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_f01e9_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 43.0%, transparent 43.0%);
# }
# #T_f01e9_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 34.2%, transparent 34.2%);
# }
# #T_f01e9_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 14.6%, transparent 14.6%);
# }
# #T_f01e9_row6_col3 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_f01e9_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 30.3%, transparent 30.3%);
# }
# #T_f01e9_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 24.6%, transparent 24.6%);
# }
# #T_f01e9_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 17.5%, transparent 17.5%);
# }
# #T_f01e9_row7_col3 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# #T_f01e9_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 29.9%, transparent 29.9%);
# }
# #T_f01e9_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 29.7%, transparent 29.7%);
# }
# #T_f01e9_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 14.3%, transparent 14.3%);
# }
# #T_f01e9_row8_col3 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_f01e9_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 31.0%, transparent 31.0%);
# }
# #T_f01e9_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 22.7%, transparent 22.7%);
# }
# #T_f01e9_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 9.9%, transparent 9.9%);
# }
# #T_f01e9_row9_col3, #T_f01e9_row10_col3 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_f01e9_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 21.6%, transparent 21.6%);
# }
# #T_f01e9_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 23.9%, transparent 23.9%);
# }
# #T_f01e9_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 13.6%, transparent 13.6%);
# }
# #T_f01e9_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 27.8%, transparent 27.8%);
# }
# #T_f01e9_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 21.5%, transparent 21.5%);
# }
# #T_f01e9_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 9.3%, transparent 9.3%);
# }
# #T_f01e9_row11_col3 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_f01e9_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 28.7%, transparent 28.7%);
# }
# #T_f01e9_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 17.9%, transparent 17.9%);
# }
# #T_f01e9_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 6.4%, transparent 6.4%);
# }
# #T_f01e9_row12_col3 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_f01e9_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 24.2%, transparent 24.2%);
# }
# #T_f01e9_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 15.0%, transparent 15.0%);
# }
# #T_f01e9_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 6.5%, transparent 6.5%);
# }
# #T_f01e9_row13_col3 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_f01e9_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #a97142 14.8%, transparent 14.8%);
# }
# #T_f01e9_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, Lightgray 17.7%, transparent 17.7%);
# }
# #T_f01e9_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #f0c05a 7.2%, transparent 7.2%);
# }
# #T_f01e9_row14_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# </style>
# <table id="T_f01e9">
#   <caption>Medals by Country: Summer Olympic Games [Top 15]</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Medal</th>
#       <th id="T_f01e9_level0_col0" class="col_heading level0 col0" >Bronze</th>
#       <th id="T_f01e9_level0_col1" class="col_heading level0 col1" >Silver</th>
#       <th id="T_f01e9_level0_col2" class="col_heading level0 col2" >Gold</th>
#       <th id="T_f01e9_level0_col3" class="col_heading level0 col3" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f01e9_level0_row0" class="row_heading level0 row0" >United States of America</th>
#       <td id="T_f01e9_row0_col0" class="data row0 col0" >1197</td>
#       <td id="T_f01e9_row0_col1" class="data row0 col1" >1333</td>
#       <td id="T_f01e9_row0_col2" class="data row0 col2" >2472</td>
#       <td id="T_f01e9_row0_col3" class="data row0 col3" >5002</td>
#     </tr>
#     <tr>
#       <th id="T_f01e9_level0_row1" class="row_heading level0 row1" >Russia</th>
#       <td id="T_f01e9_row1_col0" class="data row1 col0" >994</td>
#       <td id="T_f01e9_row1_col1" class="data row1 col1" >974</td>
#       <td id="T_f01e9_row1_col2" class="data row1 col2" >1220</td>
#       <td id="T_f01e9_row1_col3" class="data row1 col3" >3188</td>
#     </tr>
#     <tr>
#       <th id="T_f01e9_level0_row2" class="row_heading level0 row2" >Germany</th>
#       <td id="T_f01e9_row2_col0" class="data row2 col0" >1064</td>
#       <td id="T_f01e9_row2_col1" class="data row2 col1" >987</td>
#       <td id="T_f01e9_row2_col2" class="data row2 col2" >1075</td>
#       <td id="T_f01e9_row2_col3" class="data row2 col3" >3126</td>
#     </tr>
#     <tr>
#       <th id="T_f01e9_level0_row3" class="row_heading level0 row3" >United Kingdom</th>
#       <td id="T

# %%
df_new.sample()
# Out:
#        Year Host_Country   region  Bronze  Gold  Silver  Is_Host  Total Medals
# 744  1992.0        Spain  Finland       2     1       4        0           7.0

# %% [markdown]
# ## Distribution of medals on a map

# %%
host_list = list(df_new.query("Is_Host == 1")['Host_Country'].value_counts().index)

medals_temp = medals.reset_index()
medals_map = pd.merge(global_polygons, medals_temp, left_on='name',right_on='region')
medals_map['Hosted'] = np.where(medals_map['name'].isin(host_list),1,0)

# %%
def rd2(x):
    return round(x, 2)

Temp = medals_map

minimum, maximum = Temp["Total"].quantile([0.05, 0.95]).apply(rd2)
mean = round(Temp["Total"].mean(), 2)

colormap = branca.colormap.LinearColormap(
    colors=["#f2f0f7", "#cbc9e2", "#9e9ac8", "#756bb1", "#54278f"],
    index=Temp["Total"].quantile([0.25, 0.5, 0.85, 0.95]),
    vmin=minimum,
    vmax=maximum,
)

colormap.caption = "Total medals"

from folium.plugins import Search
from folium.plugins import HeatMap

m = folium.Map(location=(50,0),zoom_start=3)

def style_function(x):
    return { "fillColor": colormap(x["properties"]["Total"]),
                "color": "black",
                "weight": 2,
                "fillOpacity": 0.5, }

Map_Layer = folium.GeoJson(
    Temp,
    name="Medals",
    style_function=style_function,
    tooltip=folium.GeoJsonTooltip(
        fields=["name","Total","Gold","Silver","Bronze"], aliases=["Country","Total Medals",
                                                    "Gold","Silver","Bronze"], localize=True ),
).add_to(m)

plugins.Search(Map_Layer,position='topleft',
                           search_zoom=5,placeholder="Search for a country",weight=3,
                           search_label='region',
                           geom_type='Polygon').add_to(m)

minimap = plugins.MiniMap()
m.add_child(minimap)
    
folium.LayerControl().add_to(m)
colormap.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1f6d691bd0252fd14571b878b229998 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1f6d691bd0252fd14571b878b229998&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1f6d691bd0252fd14571b878b229998 = L.map(
#                 &quot;map_e1f6d691bd0252fd14571b878b229998&quot;,
#                 {
#                     center: [50.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba566bead589c94a9d33970140e2e070 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ba566bead589c94a9d33970140e2e070.addTo(map_e1f6d691bd0252fd14571b878b229998);
#
#
#         function geo_json_19ee38c75aa901218d6aff9c83a67784_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;7&quot;: case &quot;12&quot;: case &quot;17&quot;: case &quot;20&quot;: case &quot;22&quot;: case &quot;25&quot;: case &quot;29&quot;: case &quot;31&quot;: case &quot;38&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;52&quot;: case &quot;57&quot;: case &quot;61&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;65&quot;: case &quot;66&quot;: case &quot;73&quot;: case &quot;76&quot;: case &quot;78&quot;: case &quot;79&quot;: case &quot;85&quot;: case &quot;97&quot;: case &quot;98&quot;: case &quot;100&quot;: case &quot;105&quot;: case &quot;107&quot;: case &quot;111&quot;: case &quot;118&quot;: case &quot;120&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f2f0f7ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b5b2d5ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;77&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dedcedff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;24&quot;: case &quot;37&quot;: case &quot;39&quot;: case &quot;55&quot;: case &quot;95&quot;: case &quot;115&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#54278fff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bebcdbff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;33&quot;: case &quot;48&quot;: case &quot;91&quot;: case &quot;101&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#cac8e2ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a4a1ccff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#afacd2ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;84&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c3c0ddff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;35&quot;:
#                     return {&quot;color&

# %% [markdown]
# ## Olympic medal by countries

# %%
fig, ax = plt.subplots(1,1, figsize=(16,8), facecolor=background_color)

sns.scatterplot(data=df_new.query("Is_Host == 0"), x='Year', y='Total Medals', s=45, 
                ec='black', color='#244747',ax=ax)
sns.scatterplot(data=df_new.query("Is_Host == 1"), x='Year', y='Total Medals', s=75, 
                ec='black', color='#B73832',ax=ax)

Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

ax.tick_params(axis=u'both', which=u'both',length=0)
ax.set_ylabel("Total Medals",fontfamily='monospace',loc='bottom',color='gray')
ax.set_xlabel("")

ax.set_facecolor(background_color)
ax.set_axisbelow(True)


for s in ['top','right','bottom','left']:
    ax.spines[s].set_visible(False)
    

ax.text(Xstart,Yend+80, 'Olympic Medals by Country: Hosting always helps', fontsize=15,
        fontweight='bold',fontfamily='serif',color='#323232')
ax.text(Xstart,Yend+40, 'Host Medals', fontsize=10,fontweight='bold',color='#B73832')
ax.text(Xstart,Yend+5, 'Others', fontsize=10,fontweight='bold',color='#244747')

plt.show()

# %% [markdown]
# ## Olympic Medals by Country: Hosts through the years

# %%
fig, ax = plt.subplots(1,1, figsize=(16, 8), facecolor=background_color)

# top 20
top_list_ = df_new.groupby('region')['Total Medals'].mean().sort_values(ascending=False)\
.reset_index()[:20].sort_values(by='Total Medals',ascending=True)

plot = 1
for country in top_list_['region']:
    mean = df_new[df_new['region'] == country].groupby('region')['Total Medals'].mean()
    # historic scores
    sns.scatterplot(data=df_new[df_new['region'] == country], y=plot, x='Total Medals',
                    color='lightgray',s=50,ax=ax)
    # mean score
    sns.scatterplot(data=df_new[df_new['region'] == country], y=plot, x=mean,color='#244747',
                    ec='black',linewidth=1,s=75,ax=ax)
    # Hosting score
    sns.scatterplot(data=(df_new[(df_new['region'] == country) & (df_new['Is_Host'] == 1)]), 
                    y=plot, x='Total Medals',color='#B73832',ec='black',linewidth=1,s=75,ax=ax)   
    plot += 1

Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

ax.set_yticks(top_list_.index+1)
ax.set_yticklabels(top_list_['region'][::-1], fontdict={'horizontalalignment': 'right'}, alpha=0.7)
ax.tick_params(axis=u'both', which=u'both',length=0)
ax.set_xlabel("Total Medals",fontfamily='monospace',loc='left',color='gray')
ax.set_facecolor(background_color)
ax.hlines(y=top_list_.index+1, xmin=0, xmax=Xend, color='gray', alpha=0.5, linewidth=.3, linestyles='--')
ax.set_axisbelow(True)

for s in ['top','right','bottom','left']:
    ax.spines[s].set_visible(False)
    
ax.text(0,Yend+3.5, 'Olympic Medals by Country: Hosts through the years', fontsize=15,
                                                            fontweight='bold', color='#323232')
ax.text(0,Yend+2.1, 'Hosting', fontsize=10,fontweight='bold', color='#B73832')
ax.text(0,Yend+1, 'Average', fontsize=10,fontweight='bold', color='#244747')

plt.show()

# %% [markdown]
# ## Host countries on map with total medal over years
# Folium makes it easy to visualize data that's been manipulated in Python on an interactive leaflet map.
# https://python-visualization.github.io/folium/latest/

# %%
Temp = medals_map

colormap = branca.colormap.LinearColormap(
    colors=["#f2f0f7",  "#B73832"],
    index=Temp["Hosted"].quantile([0.05, 0.5]),
    vmin=0,
    vmax=1, )

colormap.caption = "Hosted"

from folium.plugins import Search
from folium.plugins import HeatMap

m = folium.Map(location=(50,0),zoom_start=3)

def style_function(x):
    return { "fillColor": colormap(x["properties"]["Hosted"]),
                "color": "black",
                "weight": 2,
                "fillOpacity": 0.5,   }

Map_Layer = folium.GeoJson(
    Temp,
    name="Hosted",
    style_function=style_function,
    tooltip=folium.GeoJsonTooltip(
        fields=["name","Total","Gold","Silver","Bronze"], aliases=["Country",
                                "Total Medals","Gold","Silver","Bronze"], localize=True
    ),
).add_to(m)

plugins.Search(Map_Layer,position='topleft',
                           search_zoom=5,placeholder="Search for a country",weight=3,
                           search_label='region',
                           geom_type='Polygon').add_to(m)

minimap = plugins.MiniMap()
m.add_child(minimap)
    
folium.LayerControl().add_to(m)
colormap.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b75547cf2dae74f703c67abc3787b0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b75547cf2dae74f703c67abc3787b0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b75547cf2dae74f703c67abc3787b0b = L.map(
#                 &quot;map_7b75547cf2dae74f703c67abc3787b0b&quot;,
#                 {
#                     center: [50.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c7c211ef7edae037ac92198a1c60824 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6c7c211ef7edae037ac92198a1c60824.addTo(map_7b75547cf2dae74f703c67abc3787b0b);
#
#
#         function geo_json_f4a17a67d469aa4ad0c5901248307a67_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;36&quot;: case &quot;38&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;56&quot;: case &quot;57&quot;: case &quot;59&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;65&quot;: case &quot;66&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;79&quot;: case &quot;80&quot;: case &quot;82&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;87&quot;: case &quot;88&quot;: case &quot;89&quot;: case &quot;90&quot;: case &quot;91&quot;: case &quot;92&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;96&quot;: case &quot;97&quot;: case &quot;98&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;107&quot;: case &quot;108&quot;: case &quot;109&quot;: case &quot;110&quot;: case &quot;111&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;114&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;119&quot;: case &quot;120&quot;: case &quot;121&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f2f0f7ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b73832ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_f4a17a67d469aa4ad0c5901248307a67_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f4a17a67d469aa4ad0c5901248307a67 = L.geoJson(null, {
#                 onEachFeature: geo_json_f4a17a67d469aa4ad0c590124830

# %% [markdown]
# ## Total Olympic Medals for the United States of America

# %%
temp = df_new.query("region == 'United States of America'")

fig, ax = plt.subplots(1, 1, figsize=(16, 8), facecolor=background_color)

color = ['#B73832' if i == 1 else '#244747' for i in temp['Is_Host']]

ax.bar(temp['Year'], temp['Total Medals'],width=3, color=color, ec='black')
ax.set_facecolor(background_color)
ax.grid(which='both', axis='y', zorder=5, color='gray', linestyle=':', dashes=(1,5))
ax.set_axisbelow(True)

for s in ['top', 'right']:
    ax.spines[s].set_visible(False)

Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

ax.text(Xstart,Yend+50, 'Total Olympic Medals for the United States of America', fontsize=15,
        fontweight='bold',color='#323232')
ax.text(Xstart,Yend+25, 'Hosting', fontsize=10,fontweight='bold',color='#B73832')

plt.show()

# %% [markdown]
# ## Olympic Medals for the United Kingdom

# %%
stack_temp = df_new.query("region == 'United Kingdom' & Year > 1945")[['Year','Bronze','Silver','Gold']].set_index('Year')
stack_temp = (stack_temp.T/stack_temp.sum(axis=1)).cumsum().T

fig, ax = plt.subplots(1,1, figsize=(18,5), facecolor=background_color)

# Host years
ax.axvspan(1950,1946, facecolor='lightgray',alpha=0.7)
ax.axvspan(2014,2010, facecolor='lightgray',alpha=0.7)

color = ["#a97142", "lightgray", '#f0c05a']
medals_list = ['Bronze', 'Silver', 'Gold']

for i, medal in enumerate(medals_list[::-1]):
    sentims = stack_temp[medal]
    ax.bar(sentims.index, sentims, color=color[::-1][i], label=medal, width=2.25, ec='black')

ax.set_facecolor(background_color)

for s in ['top', 'right']:
    ax.spines[s].set_visible(False)
    
Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

ax.set_xlim(Xstart+3, Xend)
ax.grid(which='both', axis='x', zorder=5, color='gray', linestyle=':', dashes=(1,5))
ax.set_axisbelow(True)
ax.get_yaxis().set_visible(False)

ax.text(Xstart+3,Yend+0.13, 'Olympic Medals for the United Kingdom', fontsize=15,fontweight='bold',
                                                                            color='#323232')
ax.text(Xstart+3,Yend+0.055, 'Hosting', fontsize=10,fontweight='bold', color='gray')

plt.show()

# %% [markdown]
# ## Overall medal distribution

# %%
fig = plt.figure(figsize=(18,10), facecolor=background_color)

colors = ['#a97142', 'lightgray', '#f0c05a', '#244747']

num = 0
variables = ['Bronze', 'Silver', 'Gold', 'Total Medals']

plots = [(0,0), (0,1), (0,2), (1,0)]

data = df_new

for item in variables:
    if plots[num] == plots[-1]:
        colspan=3
    else: 
        colspan=1
        
    plt.subplot2grid((2,3), (plots[num]), colspan=colspan)
    
    ax = sns.kdeplot(data=data, x=item,color=colors[num],fill=True,  alpha=0.9, ec='black', cut=5)
    ax.set_facecolor(background_color)
    ax.tick_params(axis='y', left=False)
    ax.get_yaxis().set_visible(False)
    ax.set_axisbelow(True)
    ax.set_xlabel(item)
    ax.grid(which='major', axis='x', zorder=5, color='gray', linestyle=':', dashes=(1,5))
    for s in ["top","right","left"]:
        ax.spines[s].set_visible(False)
    
    plt.xticks(list(np.arange(0,data[item].max()+25,25)))
    num +=1 

    
Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

fig.text(0.03,1.05, 'Overall Distribution of Medals: Positively Skewed', fontsize=25,
         fontweight='bold',color='#323232')
   
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We note that the medals are not distributed normally. They are positively skewed. To mitigate against this, I will take the natural log of the total medals.

# %%
host_list = list(df_new.query("Is_Host == 1")['Host_Country'].value_counts().index)

df_new['Total_Medals_NaturalLog'] = np.log(df_new['Total Medals'])

Not_hosting_samples = df_new[df_new['region'].isin(host_list)]\
.query("Is_Host == 0")['Total_Medals_NaturalLog'].count()

hosting_samples = df_new[df_new['region'].isin(host_list)]\
.query("Is_Host == 1")['Total_Medals_NaturalLog'].count()

Not_hosting_mean = df_new[df_new['region'].isin(host_list)]\
.query("Is_Host == 0")['Total_Medals_NaturalLog'].mean()

hosting_mean = df_new[df_new['region'].isin(host_list)]\
.query("Is_Host == 1")['Total_Medals_NaturalLog'].mean()

Not_hosting_std = df_new[df_new['region'].isin(host_list)]\
.query("Is_Host == 0")['Total_Medals_NaturalLog'].std()

hosting_std = df_new[df_new['region'].isin(host_list)].\
query("Is_Host == 1")['Total_Medals_NaturalLog'].std()

# %%
print(color_font.S+"Key Statistics"+color_font.E)
print("Mean Natural Log of Total Medals when Not Hosting:\n",Not_hosting_mean)
print("Mean Natural Log of Total Medals when Hosting:\n",hosting_mean,"\n")

Not_hosting_std_error = Not_hosting_std/np.sqrt(Not_hosting_samples)
print("Standard Error of Natural Log of Total Medals when Not Hosting:\n",Not_hosting_std_error)

hosting_std_error = hosting_std/np.sqrt(hosting_samples)
print("Standard Error of Natural Log of Total Medals when Not Hosting:\n",hosting_std_error)
# Out:
# Key Statistics
# Mean Natural Log of Total Medals when Not Hosting:
#  3.086281690114543
# Mean Natural Log of Total Medals when Hosting:
#  4.566512430214569
#
# Standard Error of Natural Log of Total Medals when Not Hosting:
#  0.06927049040753175
# Standard Error of Natural Log of Total Medals when Not Hosting:
#  0.19153671012884035

# %% [markdown]
# ## Comparing Means when Hosting & Not Hosting

# %%
fig, ax = plt.subplots(1,1, figsize=(16,8), facecolor=background_color)
ax.set_facecolor(background_color)
sns.kdeplot(data=df_new[df_new['region'].isin(host_list)].query("Is_Host == 1"), 
            x='Total_Medals_NaturalLog',fill=True,color='#B73832',alpha=0.9, ax=ax)
sns.kdeplot(data=df_new[df_new['region'].isin(host_list)].query("Is_Host == 0"), 
            x='Total_Medals_NaturalLog', fill=True, color='#244747',alpha=0.7, ax=ax)

ax.axvline(color='lightgray',x=Not_hosting_mean+(3*Not_hosting_std_error))
ax.axvline(color='lightgray',x=Not_hosting_mean-(3*Not_hosting_std_error))
ax.axvspan(Not_hosting_mean-(3*Not_hosting_std_error), Not_hosting_mean+(3*Not_hosting_std_error), 
           alpha=0.5, color='#f3f2f1')

#ax.axvline(x=Not_hosting_mean)

#ax.axvline(x=hosting_mean)
ax.axvline(color='lightgray',x=hosting_mean+(3*hosting_std_error))
ax.axvline(color='lightgray',x=hosting_mean-(3*hosting_std_error))
ax.axvspan(hosting_mean-(3*hosting_std_error), hosting_mean+(3*hosting_std_error), 
           alpha=0.5, color='#f3f2f1')

for s in ['top','left', 'bottom', 'right']:
    ax.spines[s].set_visible(False)
    
ax.set_xlabel("Natural Log of Total Medals",fontfamily='monospace',loc='left',color='gray')
ax.get_yaxis().set_visible(False)
ax.tick_params(axis = 'both', which = 'major', labelsize = 10)

ax.tick_params(axis='both', which='both',left=False, bottom=False,labelbottom=True) 

Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

ax.text(Xstart,Yend, 'Comparing Means when Hosting & Not Hosting', fontsize=15,
        fontweight='bold',color='#323232')
ax.text(Xstart,Yend-0.02, 'Hosting', fontsize=10,fontweight='bold',color='#B73832')

plt.show()

# %% [markdown]
# Above we have plotted the distributions of the natural log of the mean total medals host nations have acheived when they host, and when they do not host.
#
# The grey boxes reprseent 3 standard errors above & below the mean values. We note that these areas do not overlap. This suggests that the liklihood that hosting does not imprive performance is extremely small. In fact, it is overwhelmingly small.
