# %% [markdown]
# # Seaborn Part 2

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### Import GPU Statistics CSV

# %% [markdown]
# #### The dataset contains of 495 GPU models. It includes the following parameters:
#
# - GPU manufacturer
# - GPU class
# - Name
# - Year of release
# - Fab = fabrication process (nm). It defines the size of transistors in a processor. The transistors are the buildings block of any integrated circuit, GPU and CPU included.
# - Number of transistors (millions)
# - Die(small block of semiconducting material on IC) size
# - Memory size in megabytes
# - GFLOPS = billions of Floating Operations Per Second
# - TDP (thermal design power) = the maximum amount of heat generated by a computer chip or component

# %%
df = pd.read_csv('gpus.csv')
df
# Out:
#     Manufacturer       Class                   Name  Year  Fab  \
# 0         Nvidia     Desktop        GeForce 8300 GS  2007   80
# 1         Nvidia     Desktop        GeForce 8400 GS  2007   80
# 2         Nvidia     Desktop  GeForce 8400 GS rev.2  2007   65
# 3         Nvidia     Desktop  GeForce 8400 GS rev.3  2010   40
# 4         Nvidia     Desktop        GeForce 8500 GT  2007   80
# ..           ...         ...                    ...   ...  ...
# 490   AMD Radeon  Datacenter    Radeon Instinct MI6  2016   14
# 491   AMD Radeon  Datacenter    Radeon Instinct MI8  2016   28
# 492   AMD Radeon  Datacenter   Radeon Instinct MI25  2016   14
# 493   AMD Radeon  Datacenter   Radeon Instinct MI50  2018    7
# 494   AMD Radeon  Datacenter   Radeon Instinct MI60  2018    7
#
#      Transistors (mln)  Die size  Memory size  Memory speed   GFLOPS    TDP
# 0                  210       127          512           6.4     14.4   40.0
# 1                  210       127          512           6.4     28.8   40.0
# 2                  210        86          512           6.4     24.4   25.0
# 3                  260        57         1024           9.6     19.7   25.0
# 4                  210       127         1024          12.8     28.8   45.0
# ..                 ...       ...          ...           ...      ...    ...
# 490               5700       232        16384         224.0   5800.0  150.0
# 491               8900       596         4096         512.0   8200.0  175.0
# 492              12500       510        16384         436.2  12300.0  300.0
# 493              13200       331        16384        1024.0  13400.0  300.0
# 494              13200       331        32768        1024.0  14725.0  300.0
#
# [495 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Manufacturer       495 non-null    object
#  1   Class              495 non-null    object
#  2   Name               495 non-null    object
#  3   Year               495 non-null    int64
#  4   Fab                495 non-null    int64
#  5   Transistors (mln)  495 non-null    int64
#  6   Die size           495 non-null    int64
#  7   Memory size        495 non-null    int64
#  8   Memory speed       495 non-null    float64
#  9   GFLOPS             495 non-null    float64
#  10  TDP                495 non-null    float64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 42.7+ KB

# %%
max_transistors_per_year = df.groupby('Year')['Transistors (mln)'].max()
max_transistors_per_year
# Out:
# Year
# 2007      754
# 2008     1912
# 2009     4308
# 2010     3100
# 2011     6000
# 2012     7080
# 2013     8626
# 2014    14160
# 2015     8900
# 2016    17800
# 2017    21100
# 2018    21100
# 2019    26460
# 2020    54200
# Name: Transistors (mln), dtype: int64

# %%
type(max_transistors_per_year)
# Out:
# pandas.core.series.Series

# %% [markdown]
# [text](#Transistor-density)

# %%
df.loc[(df.Fab==28)&(df.Year==2014)].groupby('Manufacturer')['Name'].count()
# Out:
# Manufacturer
# AMD Radeon    19
# Nvidia        20
# Name: Name, dtype: int64

# %%
plt.figure(figsize=(15, 10))
ax1 = sns.scatterplot(data=df, x='Year',  y='Transistors (mln)',  
                     legend='full', hue='Fab',
                     palette = sns.color_palette("Set1", n_colors=len(df.Fab.unique())))
sns.lineplot(data = max_transistors_per_year, ax = ax1.axes, color='black')
ax1.set_xlim(2006, 2021)
plt.show()

# %% [markdown]
# ### Transistor density

# %%
df.loc[df.index, 'Transistors/mm2'] = df['Transistors (mln)'] / df['Die size']
df
# Out:
#     Manufacturer       Class                   Name  Year  Fab  \
# 0         Nvidia     Desktop        GeForce 8300 GS  2007   80
# 1         Nvidia     Desktop        GeForce 8400 GS  2007   80
# 2         Nvidia     Desktop  GeForce 8400 GS rev.2  2007   65
# 3         Nvidia     Desktop  GeForce 8400 GS rev.3  2010   40
# 4         Nvidia     Desktop        GeForce 8500 GT  2007   80
# ..           ...         ...                    ...   ...  ...
# 490   AMD Radeon  Datacenter    Radeon Instinct MI6  2016   14
# 491   AMD Radeon  Datacenter    Radeon Instinct MI8  2016   28
# 492   AMD Radeon  Datacenter   Radeon Instinct MI25  2016   14
# 493   AMD Radeon  Datacenter   Radeon Instinct MI50  2018    7
# 494   AMD Radeon  Datacenter   Radeon Instinct MI60  2018    7
#
#      Transistors (mln)  Die size  Memory size  Memory speed   GFLOPS    TDP  \
# 0                  210       127          512           6.4     14.4   40.0
# 1                  210       127          512           6.4     28.8   40.0
# 2                  210        86          512           6.4     24.4   25.0
# 3                  260        57         1024           9.6     19.7   25.0
# 4                  210       127         1024          12.8     28.8   45.0
# ..                 ...       ...          ...           ...      ...    ...
# 490               5700       232        16384         224.0   5800.0  150.0
# 491               8900       596         4096         512.0   8200.0  175.0
# 492              12500       510        16384         436.2  12300.0  300.0
# 493              13200       331        16384        1024.0  13400.0  300.0
# 494              13200       331        32768        1024.0  14725.0  300.0
#
#      Transistors/mm2
# 0           1.653543
# 1           1.653543
# 2           2.441860
# 3           4.561404
# 4           1.653543
# ..               ...
# 490        24.568966
# 491        14.932886
# 492        24.509804
# 493        39.879154
# 494        39.879154
#
# [495 rows x 12 columns]

# %%
df.Fab.unique()
# Out:
# array([80, 65, 40, 90, 55, 28, 14, 16, 12,  8,  7], dtype=int64)

# %%
plt.figure(figsize=(15, 10))
ax2 = sns.scatterplot(data=df, x='Year', y='Transistors/mm2',
                     hue='Fab', legend='full',
                     palette=sns.color_palette("Set1", n_colors=len(df.Fab.unique())))
ax = sns.regplot(data=df, x='Year', y='Transistors/mm2', scatter=False,
                 ax=ax2.axes, order=4)
ax.set_xlim(2006, 2021)
ax.set_ylim(0, 70)
# Out:
# (0.0, 70.0)

# %% [markdown]
# ### GPU’s Class vs TDP

# %%
df['Class'].unique()
# Out:
# array(['Desktop', 'Workstation', 'Datacenter'], dtype=object)

# %%
df.describe()
# Out:
#               Year         Fab  Transistors (mln)     Die size   Memory size  \
# count   495.000000  495.000000         495.000000   495.000000    495.000000
# mean   2012.880808   33.957576        4712.228283   307.777778   5493.793939
# std       3.681106   18.034835        6645.950201   210.542453   7834.893178
# min    2007.000000    7.000000         180.000000    57.000000     64.000000
# 25%    2010.000000   28.000000         754.000000   132.000000   1024.000000
# 50%    2013.000000   28.000000        2200.000000   256.000000   2048.000000
# 75%    2016.000000   40.000000        6100.000000   438.000000   6144.000000
# max    2020.000000   90.000000       54200.000000  1192.000000  65536.000000
#
#        Memory speed        GFLOPS         TDP  Transistors/mm2
# count    495.000000    495.000000  495.000000       495.000000
# mean     201.327709   3548.423818  145.768485        12.988545
# std      255.778339   5102.158541   98.177831        10.980187
# min        3.200000     14.400000   12.000000         1.407025
# 25%       51.200000    480.000000   59.000000         4.949153
# 50%      112.100000   1344.000000  134.000000        12.040816
# 75%      256.000000   4636.000000  225.000000        14.155251
# max     2048.000000  40000.000000  600.000000        65.617433

# %%
sns.set(style="white", palette="muted", color_codes=True)
sns.displot(data=df, x="TDP", hue="Class", col="Class", kde=True)

# %%
df.loc[df['Class']=='Datacenter']['TDP'].median()
# Out:
# 225.0

# %%
df.loc[df['Class']=='Desktop']['TDP'].skew()
# Out:
# 0.8215194558499305

# %%
df.loc[df['Class']=='Workstation']['TDP'].skew()
# Out:
# 1.5345385177070925

# %%
df.loc[df['Class']=='Datacenter']['TDP'].skew()
# Out:
# -0.27312304470699533

# %% [markdown]
# ### TDP on FAB from 2 Manufacturers

# %%
df['Manufacturer'].unique()
# Out:
# array(['Nvidia', 'AMD Radeon'], dtype=object)

# %%
sorted(df['Fab'].unique())
# Out:
# [7, 8, 12, 14, 16, 28, 40, 55, 65, 80, 90]

# %%
df.loc[df['Manufacturer']=='Nvidia']['TDP'].describe()
# Out:
# count    245.000000
# mean     152.057143
# std       95.553654
# min       12.000000
# 25%       64.000000
# 50%      150.000000
# 75%      225.000000
# max      600.000000
# Name: TDP, dtype: float64

# %%
df.loc[df['Manufacturer']=='AMD Radeon']['TDP'].describe()
# Out:
# count    250.000000
# mean     139.605600
# std      100.492429
# min       15.000000
# 25%       55.000000
# 50%      122.500000
# 75%      218.750000
# max      500.000000
# Name: TDP, dtype: float64

# %%
df.loc[(df.Fab==28)&(df.Year==2014)].groupby('Manufacturer')['Name'].count()

# %%
plt.figure(figsize=(15, 10))
sns.violinplot(data=df, x='Fab', y='TDP', linewidth=1.5,
               hue='Manufacturer', density_norm='width', alpha=0.5,
               split=True,  # split the violin half
               bw_method=.5,       # scale factor for kernel bandwidth
               cut=0.1,     # distance, in units of bandwidth size
               palette=sns.color_palette(['green', 'red']))
ax.set(ylim=(0, 700))
# Out:
# [(0.0, 700.0)]

# %% [markdown]
# ## Stripplot and pointplot

# %%
plt.subplots(figsize=(10, 7))
sns.despine(bottom=True, left=True)

sns.stripplot(x="TDP", y="Class", hue="Manufacturer",
              data=df, dodge=.5, alpha=.55, zorder=1)

sns.pointplot(x="TDP", y="Class", hue="Manufacturer",
              data=df, dodge=.5, linestyle='none', 
              markers="D", linewidth=2, errorbar=('ci', 95),
             palette=sns.color_palette(['green', 'red'])
             )

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[2:], labels[2:], title="Class",
          handletextpad=0, columnspacing=1,
          loc="best", ncol=2, frameon=True)

# %% [markdown]
# ## lmplot() associates with regplot()

# %% [markdown]
# GFLOPS = billions of Floating Operations Per Second

# %%
sns.set_theme()
sns.lmplot(x='Year', y='GFLOPS', data=df, hue='Fab', fit_reg=False, height=10)
sns.regplot(x='Year', y='GFLOPS', data=df, scatter=False,  order=3)
# Out:
# <Axes: xlabel='Year', ylabel='GFLOPS'>

# %% [markdown]
# ## Compare the number of GFLOPS per million of transistors

# %%
df['GFLOPS/transistors'] = df['GFLOPS'] / df['Transistors (mln)']
df
# Out:
#     Manufacturer       Class                   Name  Year  Fab  \
# 0         Nvidia     Desktop        GeForce 8300 GS  2007   80
# 1         Nvidia     Desktop        GeForce 8400 GS  2007   80
# 2         Nvidia     Desktop  GeForce 8400 GS rev.2  2007   65
# 3         Nvidia     Desktop  GeForce 8400 GS rev.3  2010   40
# 4         Nvidia     Desktop        GeForce 8500 GT  2007   80
# ..           ...         ...                    ...   ...  ...
# 490   AMD Radeon  Datacenter    Radeon Instinct MI6  2016   14
# 491   AMD Radeon  Datacenter    Radeon Instinct MI8  2016   28
# 492   AMD Radeon  Datacenter   Radeon Instinct MI25  2016   14
# 493   AMD Radeon  Datacenter   Radeon Instinct MI50  2018    7
# 494   AMD Radeon  Datacenter   Radeon Instinct MI60  2018    7
#
#      Transistors (mln)  Die size  Memory size  Memory speed   GFLOPS    TDP  \
# 0                  210       127          512           6.4     14.4   40.0
# 1                  210       127          512           6.4     28.8   40.0
# 2                  210        86          512           6.4     24.4   25.0
# 3                  260        57         1024           9.6     19.7   25.0
# 4                  210       127         1024          12.8     28.8   45.0
# ..                 ...       ...          ...           ...      ...    ...
# 490               5700       232        16384         224.0   5800.0  150.0
# 491               8900       596         4096         512.0   8200.0  175.0
# 492              12500       510        16384         436.2  12300.0  300.0
# 493              13200       331        16384        1024.0  13400.0  300.0
# 494              13200       331        32768        1024.0  14725.0  300.0
#
#      Transistors/mm2  GFLOPS/transistors
# 0           1.653543            0.068571
# 1           1.653543            0.137143
# 2           2.441860            0.116190
# 3           4.561404            0.075769
# 4           1.653543            0.137143
# ..               ...                 ...
# 490        24.568966            1.017544
# 491        14.932886            0.921348
# 492        24.509804            0.984000
# 493        39.879154            1.015152
# 494        39.879154            1.115530
#
# [495 rows x 13 columns]

# %%
ax = sns.PairGrid(df[['Year', 'Transistors/mm2', 'GFLOPS/transistors']], 
                 diag_sharey=False, height=4)
ax.map_upper(sns.scatterplot, color='g')
ax.map_lower(sns.kdeplot, color='r' )
ax.map_diag(sns.kdeplot, lw=1, fill=True)

plt.show()

# %% [markdown]
# ## Memory speed of two manufacturers

# %%
ax = sns.catplot(x="Year", y="Memory speed", hue="Manufacturer", height=6, aspect=2,
                 capsize=.2, kind="point", data=df)
plt.show()

# %%
ax = sns.lmplot(x='Transistors (mln)', y='GFLOPS', data=df, hue='Year', fit_reg=False,
                palette=sns.color_palette('RdBu', n_colors=16), height=7)
sns.regplot(x='Transistors (mln)', y='GFLOPS', data=df, scatter=False, ax=ax.axes[0, 0], order=2)
ax.axes[0, 0].set_xlim((0, 57000))
plt.show()

# %%
df.loc[df['Transistors (mln)'] == df['Transistors (mln)'].max()]
# Out:
#     Manufacturer       Class       Name  Year  Fab  Transistors (mln)  \
# 239       Nvidia  Datacenter  GRID A100  2020    7              54200
# 240       Nvidia  Datacenter  A100 SXM4  2020    7              54200
# 241       Nvidia  Datacenter  A100 PCIe  2020    7              54200
#
#      Die size  Memory size  Memory speed   GFLOPS    TDP  Transistors/mm2  \
# 239       826        49152        1866.0  13890.0  400.0        65.617433
# 240       826        40960        1555.0  19490.0  400.0        65.617433
# 241       826        40960        1555.0  19490.0  250.0        65.617433
#
#      GFLOPS/transistors
# 239            0.256273
# 240            0.359594
# 241            0.359594

# %%
ax = sns.lmplot(x='Transistors (mln)', y='GFLOPS', data=df, hue='Year', fit_reg=False,
                palette=sns.color_palette('RdBu', n_colors=16), height=7)
sns.regplot(x='Transistors (mln)', y='GFLOPS', data=df, scatter=False, ax=ax.axes[0, 0], order=2)
plt.text(54000, 19000, 'A100 SXM4 / A100 PCIe', ha='right')
plt.text(54000, 13000, 'GRID A100', ha='right')
ax.axes[0, 0].set_xlim((0, 57000))
plt.show()

# %% [markdown]
# ## growth of GFLOPS per number of transistors

# %%
sns.jointplot(x='Year', y='GFLOPS/transistors', data=df,
              kind="reg", truncate=False, marginal_kws={'bins': 14},
              xlim=(2006, 2021),
              color="m", height=7)
plt.show()
