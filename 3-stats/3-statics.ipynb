# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /Users/bohui/.pyenv/versions/3.11.12/bin/python
# 3.11.12 (main, May 14 2025, 21:47:57) [Clang 15.0.0 (clang-1500.3.9.4)]

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from scipy.stats import kurtosis, norm

data = norm.rvs(size=245, random_state=5)
k = kurtosis(data, fisher=False)
k
# Out:
# 3.0069584217793115
