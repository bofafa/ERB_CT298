# %%
a = [1,2,3,4,5]
b = [2,3,1,3,4]

# %%
list(map(lambda x :'Pass' if x >=2 else 'Fail', a))
# Out:
# ['Fail', 'Pass', 'Pass', 'Pass', 'Pass']

# %%
list(map(lambda x, y: x if x >= y else y, a, b))
# Out:
# [2, 3, 3, 4, 5]

# %%
list(map(lambda i, j: i if i >= j else j, a,b))
# Out:
# [2, 3, 3, 4, 5]

# %%
result = [x for x, y in zip(a, b) if x >= y]

result
# Out:
# [3, 4, 5]
