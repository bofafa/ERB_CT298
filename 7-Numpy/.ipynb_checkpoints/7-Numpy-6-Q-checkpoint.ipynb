# %% [markdown]
# # Universal Function

# %%
import numpy as np
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# ## 53. Numpy power and square root
# <pre>Find the following value in numpy array
# 1. Power 2 of array([1, 2, 3])
# 2. Square root of array([4, 9, 16])
#
# Desire Output:
# $> [1 4 9]
# $> [2. 3. 4.]</pre>

# %%
np.array([1,2,3])** 2
# Out:
# array([1, 4, 9])

# %%
np.power([1,2,3], 2)
# Out:
# array([1, 4, 9])

# %%
np.sqrt([4,9,16])
# Out:
# array([2., 3., 4.])

# %% [markdown]
# # np.logical_and

# %% [markdown]
# ## 54. Negation of numpy boolean array
# <pre>Find the negation of array
# Given Input:
# a = np.array([True, False, True])
#
# Desired Output:
# not a: [False  True False]</pre>

# %%
a = np.array([True, False, True])
np.logical_not(a)
# Out:
# array([False,  True, False])

# %% [markdown]
# ## 55. Element-wise logical operations on two arrays
# <pre>Find the logical value of a and b
# Given Input:
# a = np.array([False, True, False, True])
# b = np.array([False, False, True, True])
#
# Desired Output:
# a and b: [False False False  True]
# a or b: [False  True  True  True]
# a xor b: [False  True  True False]</pre>

# %%
a = np.array([False, True, False, True])
b = np.array([False, False, True, True])

np.logical_and(a, b)

np.logical_xor(a,b)
# Out:
# array([False,  True,  True, False])

# %%
np.logical_or(a,b)
# Out:
# array([False,  True,  True,  True])

# %%
np.logical_xor(a,b) #<--只得一個 True 先 True
# Out:
# array([False,  True,  True, False])

# %% [markdown]
# ## 56. Performs unbuffered in place operation on operand
# <pre>Make negative the a first and second column, and return a
# Given Input:
# a = np.array([1, 2, 3, 4])
#
# Desired Output:
# array([-1, -2,  3,  4])</pre>

# %%
a = np.array([1, 2, 3, 4])
np.negative.at(a,[0,1])
a
# Out:
# array([-1, -2,  3,  4])

# %% [markdown]
# # np.add.at

# %% [markdown]
# ## 57. Performs unbuffered in place operation on operand
# ### a 的 [0,1] 加b
# <pre>Add items 0 and 1 in a to b, and store results in a
# a = np.array([1, 2, 3, 4])
# b = np.array([1, 2])
#
# Desired Output:
# $> a
# array([2, 4, 3, 4])</pre>

# %%
a = np.array([1, 2, 3, 4])
b = np.array([1, 2])
np.add.at(a,[0,1],b)
a
# Out:
# array([2, 4, 3, 4])

# %% [markdown]
# # np.add.accumulate()

# %% [markdown]
# ## 58. Accumulate the result of applying the operator to all elements 累積加法
# <pre>Find the accumulate value by addition and multiplication of a
# Given Input:
# a = np.array([1, 2, 3])
#
# Desired Output:
# array([1, 3, 6])
# array([1, 2, 6])
# </pre>

# %%
a = np.array([1, 2, 3])

# %%
# np.add.accumulate() equal np.cumsum()
np.add.accumulate(a) #累積加法
# Out:
# array([1, 3, 6])

# %%
# multiply.accumulate() 
np.multiply.accumulate(a) #累積乘法
# Out:
# array([ 2,  8, 24, 96])

# %% [markdown]
# # np.multiply.reduce <-- it was array, now change to scaler

# %% [markdown]
# ## 59. Reduces array’s dimension by one, by applying ufunc along one axis.
# <pre>Try the folowing 3 function and write down its calcualting logics
# np.multiply.reduce(a)
# np.add.reduce(a)
# np.power.reduce(a)
#
# Given Input:
# a = np.array([2,3,4])
#
# Desired Output:
# 24
# 9
# 4096</pre>

# %%
a = np.array([2,3,4])

# %%
# = 2*3*4
# np.multiply.reduce() equal to np.prod() 
# np.multiply is ufun
np.multiply.reduce(a)
# Out:
# 96

# %%
# np.add.reduce() equal to np.sum()
np.add.reduce(a)
# Out:
# 9

# %%
# = (2**3)**4  ;  use np.power.reduce()
np.power.reduce(a)
# Out:
# 4096

# %% [markdown]
# ## 60. Compute the outer product of two given vectors 外積
# <pre>
# Given Input:
# a = np.array([1, 2, 3])
# b = np.array([4, 5, 6])
#
# Desired Output:
# array([[ 4,  5,  6],
#        [ 8, 10, 12],
#        [12, 15, 18]])</pre>

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# %%
# np.multiply.outer()
np.multiply.outer(a,b)
# Out:
# array([[ 4,  5,  6],
#        [ 8, 10, 12],
#        [12, 15, 18]])

# %%
# array([ 4, 10, 18])
np.multiply(a,b)
# Out:
# array([ 4, 10, 18])

# %% [markdown]
# ## 61. First array elements raised to powers from second array
# <pre>Use np.float_power(x1, x2) to the positionally-corresponding power
# Given Input:
# a = np.array([1, 2, 3])
# b = np.array([0, 2, 4])
#
# Desired Output:
# array([ 1.,  4., 81.])</pre>

# %%
a = np.array([1, 2, 3])
b = np.array([0, 2, 4])

# %%
np.float_power(a, b)
# Out:
# array([ 1.,  4., 81.])

# %% [markdown]
# ## 62. Returns the element-wise remainder of division
# <pre>Find the remainder of division from a b
# Given Input:
# a = np.array([3, 5, 7])
# b = np.array([2, 3, 4])
#
# Desired Output:
# array([1, 2, 3])</pre>

# %%
a = np.array([3, 5, 7])
b = np.array([2, 3, 4])

# %%
np.remainder(a,b)
# Out:
# array([1, 2, 3])

# %%
# The % operator can be used as a shorthand for np.remainder on ndarrays
a % b
# Out:
# array([1, 2, 3])

# %%
np.mod(a,b)
# Out:
# array([1, 2, 3])

# %% [markdown]
# ## 63. Floor divide 計除數, 無小數點，round down
# <pre>Return the largest integer smaller or equal to the division of the inputs.
# Given Input:
# a = np.array([7, 7, 7, 11])
# b = np.array([2, 3, 4, 5])
#
# Desired Output:
# array([3, 2, 1, 2])</pre>

# %%
a = np.array([7, 7, 7, 11])
b = np.array([2, 3, 4, 5])

# %%
np.floor_divide(a,b)
# Out:
# array([3, 2, 1, 2])

# %%
a//b
# Out:
# array([3, 2, 1, 2])

# %% [markdown]
# ## 64. Natural logarithm, element-wise
# <pre>
# Try Natural logarithm: np.log()
# Try Natural logarithm of one plus log(1 + x): np.log1p()
#
# Given Input:
# a = np.array([1, 10, np.e])
#
# Desired Output:
# array([0.        , 2.30258509, 1.        ])
# array([0.69314718, 2.39789527, 1.31326169])</pre>

# %%
a = np.array([1, 10, np.e])

# %%
# array([0.        , 2.30258509, 1.        ])
np.log(a)
# Out:
# array([0.        , 2.30258509, 1.        ])

# %%
# array([0.69314718, 2.39789527, 1.31326169])
np.log1p(a)
# Out:
# array([0.69314718, 2.39789527, 1.31326169])

# %% [markdown]
# ## 65. Calculate the exponential of all elements in the input array
# <pre>Calculate exp(x)
# Calculate exp(x) - 1
#
# Given Input:
# a = np.array([1, 10, 100])
#
# Desired Output:
# array([2.71828183e+00, 2.20264658e+04, 2.68811714e+43])
# array([1.71828183e+00, 2.20254658e+04, 2.68811714e+43])
# </pre>

# %%
a = np.array([1, 10, 100])

# %%
# Out:
# array([2.71828183e+00, 2.20264658e+04, 2.68811714e+43])

# %%
# Out:
# array([1.71828183e+00, 2.20254658e+04, 2.68811714e+43])

# %% [markdown]
# ## 66. Return the non-negative square-root of an array, element-wise.
# <pre>Return square root of array
# a = np.array([1, 10, 100])</pre>

# %%
a = np.array([1, 10, 100])

# %%
np.sqrt(a)
# Out:
# array([ 1.        ,  3.16227766, 10.        ])

# %% [markdown]
# ## 67. Return the cube-root of an array, element-wise.
# <pre>Return cube root of array
# a = np.array([1, 8, 1000])</pre>

# %%
a = np.array([1, 8, 1000])

# %%
np.cbrt(a)
# Out:
# array([ 1.,  2., 10.])

# %% [markdown]
# ## 68. Returns the greatest common divisor 最多公因數

# %%
np.gcd(12, 20)
# Out:
# 4

# %%
np.gcd.reduce([15, 25, 35]) #超過2個數要用reduce
# Out:
# 5

# %%
np.gcd(np.arange(6), 20) # 0-5, 同 20 對比做 最大公因數
# Out:
# array([20,  1,  2,  1,  4,  5])

# %% [markdown]
# ## 69. Returns the lowest common multiple 最少公倍數

# %%
np.lcm(12, 20)
# Out:
# 60

# %%
np.lcm.reduce([3, 12, 20])
# Out:
# 60

# %%
np.lcm.reduce([40, 12, 20])
# Out:
# 120

# %%
np.lcm(np.arange(6), 20)
# Out:
# array([ 0, 20, 20, 60, 20, 20])

# %% [markdown]
# ## 70. Test element-wise for NaN and return result as a boolean array

# %%
np.isnan([1, 2, np.nan])
# Out:
# array([False, False,  True])

# %%
np.isnan(np.inf)
# Out:
# False

# %% [markdown]
# ## 71. Return the ceiling and floor of the input, element-wise.

# %%
a = np.array([-1.7, -1.5, -0.2, 0.2, 1.5, 1.7, 2.0])
a
# Out:
# array([-1.7, -1.5, -0.2,  0.2,  1.5,  1.7,  2. ])

# %%
np.ceil(a)
# Out:
# array([-1., -1., -0.,  1.,  2.,  2.,  2.])

# %%
np.floor(a)
# Out:
# array([-2., -2., -1.,  0.,  1.,  1.,  2.])

# %% [markdown]
# ## 72. Return the truncated value of the input, element-wise.
# The truncated value of the scalar x is the nearest integer i which is closer to zero than x is. In short, the fractional part of the signed number x is discarded.

# %%
a = np.array([-1.7, -1.5, -0.2, 0.2, 1.5, 1.7, 2.0])
a
# Out:
# array([-1.7, -1.5, -0.2,  0.2,  1.5,  1.7,  2. ])

# %%
np.trunc(a)
# Out:
# array([-1., -1., -0.,  0.,  1.,  1.,  2.])
