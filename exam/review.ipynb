# %% [markdown]
# # 1. plotly

# %%
import plotly.io as pio

fig = dict({
    "data":[{"type" : "scatter",
             "x":[1,2,3],
             "y":[1,3,2]}],
    "layout":{"title": {"text" : "python bar chart"}}
})

pio.show(fig)

# %% [markdown]
# # 2. seabron

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
cats = np.array(["A","B","C"])
nums = np.array([1,2,5])
sns.set_theme(style = 'darkgrid', palette='pastel')
sns.barplot(x=cats, y=nums)
plt.title('Seaborn Bar Plot')
plt.xlabel('x-Acis')
plt.ylabel('y-Acis')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid", palette = 'pastel')
product = ['A','B','C']
sales = [2,4,6]
sns.barplot(x= product, y=sales)
plt.title('Seaborn Bar Chart')
plt.xlabel('Product Name')
plt.ylabel('Sales Volume')
plt.show()

# %% [markdown]
# # 3.Matplotlib

# %%
import matplotlib.pyplot as plt
x= [1,2,3,4,5,6]
y=[1,2,np.nan, 4, None, 6]
plt.plot (x,y, 'r-o') #跟x, y 坐標畫線，o 在數據點上註紅點
#add x lable
plt.xlabel('x-Axis lable')
#add y lable
plt.ylabel('y-Axis lable')
#add grid
plt.grid(True)

# %% [markdown]
# # 4. Git

# %% [markdown]
# Git 是一個開源分 散式版本控制系統，用於跟蹤檔的版 本。它通常由程式師協作開發軟體來 控制原始程式碼。
# History Tracking: Git 允許您跟蹤專案中所做的每項更改，包括:誰 進行了更改以及何時進行了更改。
# Collaboration: 多個開發人員可以同時處理同一 個專案，並且 Git 可以有效地管理代碼中更改的合併
# Branching and Merging: Git 使開發人員能夠創建分支 來處理新功能或錯誤修復，然後將它們合併回主代碼庫
# Offline Work: Git 可以離線工作，這意味著即使沒有互聯網 連接，您也可以提交更改並處理您的專案
#
# git init
# git add.
# git commit -m "update"
# git branch
# git branch A
# git checkout
# git merge A

# %% [markdown]
# # 5. Data Base

# %% [markdown]
# # 6. python class

# %% [markdown]
# # 7. Array

# %% [markdown]
# # Risk and Return

# %% [markdown]
# price: VWAP, Mid-price, Adj Closing Price
# Return: CARG, Mean Return, Log Retunf
# Risk: STD, Volatility, Maxium Drawdown (in some period), Max Drop Down(daily), Skewness, Kurosis
# Ratio: Sharpe(Std), Clamar(Mdd), Sortino(-ve Std)
# Beta coefficient():indicator of the price volatility = varianace(Rm) Covariance(Re, Rm)
# Alpha a:Excess return over benchmark = Rp -[Rf +(Rm - Rf)B)]
